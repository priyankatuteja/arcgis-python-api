# %% [markdown]
# # What's new in version 1.8.3

# %% [markdown]
# ## New
# * Adds [`ujson`](https://github.com/ultrajson/ultrajson) library as a dependency for JSON parsing to improve performance

# %% [markdown]
# ### New [Guides](https://developers.arcgis.com/python/guide/)
# * Working with geometries
#   * [Part 1 - Introduction - what is geometry?](https://developers.arcgis.com/python/guide/part1-introduction-what-is-geometry/)
#   * [Part 2 - Working with Geometries](https://developers.arcgis.com/python/guide/part2-working-with-geometries/)
#   * [Part 3 - Spatial operations on geometries](https://developers.arcgis.com/python/guide/part3-spatial-operations-on-geometries/)
#   * [Part 4 - Applying spatial filters](https://developers.arcgis.com/python/guide/part4-spatial-filters/)
# * Enriching GIS data with Thematic Information
#   * [Part 1 - Introduction to GeoEnrichment](https://developers.arcgis.com/python/guide/part1-introduction-to-geoenrichment)
#   * [Part 2 - Where to enrich?(what are study areas?)](https://developers.arcgis.com/python/guide/part2-where-to-enrich-study-areas/)
#   * [Part 3 - Where to enrich?(what are Named Statistical Areas?)](https://developers.arcgis.com/python/guide/part3-where-to-enrich-named-stat-areas/)
#   * [Part 4 - What to enrich with? (What are Data Collections and Analysis Variables?)](https://developers.arcgis.com/python/guide/part4-what-to-enrich-datacollections-analysisvariables/)
#   * [Part 5 - Generating Reports](https://developers.arcgis.com/python/guide/part5-generate-reports/)
#   * [Part 6 - Standard Geography Queries](https://developers.arcgis.com/python/guide/part6-std-geography-query/)
# * Data Engineering Guides
#   * [Part 1 - Introduction to Data Engineering](https://developers.arcgis.com/python/guide/part1-introduction-to-dataengineering)
#   * [Part 2 - Introduction to NumPy](https://developers.arcgis.com/python/guide/part2-introduction-to-numpy)
#   * [Part 3 - Introduction to Pandas](https://developers.arcgis.com/python/guide/part3-introduction-to-pandas)
#   * [Part 4 - Productivity with Pandas](https://developers.arcgis.com/python/guide/part4-productivity-with-pandas)
#   * [Part 5 - Working with Time Series Data](https://developers.arcgis.com/python/guide/part5-time-series-analysis-with-pandas)
# * Install and set up
#  * Reconfigures Guide into:
#    * [Install and set up](https://developers.arcgis.com/python/guide/install-and-set-up/)
#    * [Install older versions](https://developers.arcgis.com/python/guide/install-older-versions)
# * Deep Learning with ArcGIS
#   * [Geo-Referencing and Digitization of Scanned Maps](https://developers.arcgis.com/python/guide/geo-referencing-and-digitization-of-scanned-maps)
#   * [How SuperResolution Works](https://developers.arcgis.com/python/guide/how-superresolution-works)
#   * [How Multi-Task Road Extractor works](https://developers.arcgis.com/python/guide/how-multi-task-road-extractor-works)
#   * [How Pix2Pix works](https://developers.arcgis.com/python/guide/how-pix2pix-works)
#   * [How CycleGAN Works](https://developers.arcgis.com/python/guide/how-cyclegan-works)  * [Text Classification workflow with [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)](https://developers.arcgis.com/python/guide/text-classification)

# %% [markdown]
# ### New [`Samples`](https://developers.arcgis.com/python/sample-notebooks/)
# * Org Administrators
#  * [Clone StoryMap Version 2](https://developers.arcgis.com/python/sample-notebooks/clone-storymap-version2)
# * GIS Analysts and Data Scientists
#  * [Prediction of energy generation from Solar Photovoltaic Power Plants using weather variables](https://developers.arcgis.com/python/sample-notebooks/solar-energy-prediction-using-weather-variables)
#  * [Detection of electric utility features and vegetation encroachments from satellite images using deep learning](https://developers.arcgis.com/python/sample-notebooks/detection-of-electric-utility-features-and-vegetation-encroachments-from-satellite-images-using-deep-learning)
#  * [River Turbidity Estimation using Sentinel-2 data](https://developers.arcgis.com/python/sample-notebooks/river-turbidity-estimation-using-sentinel2-data-)
#  * [Mapping Infrastructural Damage due to Beirut Blast](https://developers.arcgis.com/python/sample-notebooks/infrastructural-damage-due-to-blast-in-beirut)
#  * [Coastline extraction using Landsat-8 multispectral imagery and band ratio technique](https://developers.arcgis.com/python/sample-notebooks/coastline-extraction-usa-landsat8-multispectral-imagery)
#  * [Identifying country names from incomplete house addresses](https://developers.arcgis.com/python/sample-notebooks/identifying-country-names-from-incomplete-house-addresses)
#  * [SAR to RGB image translation using CycleGAN](https://developers.arcgis.com/python/sample-notebooks/sar-to-rgb-image-translation-using-cyclegan/)
#  * [Creating building models using point cloud classification](https://developers.arcgis.com/python/sample-notebooks/creating-building-models-using-point-cloud-classification)
#  * [Automatic road extraction using deep learning](https://developers.arcgis.com/python/sample-notebooks/automatic-road-extraction-using-deep-learning)

# %% [markdown]
#    * Adds `admins` parameter
#    * Adds default value to `usernames` parameter
# * [`DataStoreManager`]()
# * Adds logic for application login with `client_id` and `client_secret`#### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#)
# * Adds [`Workflow Manager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.workflowmanager/#) submodule
# * Adds support for `API Key` authentication to [`GIS()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis) object with `api_key` keyword
# * Adds `trust_env` keyword to [`GIS()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis)
# * Adds [`python-certifi-win32`](https://pypi.org/project/python-certifi-win32/) to API dependencies so certificates from the Windows certificate store are used by [`GIS`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis)
# * [`UserManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#usermanager)
#  * Adds code example for `role` parameter on [`create()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.UserManager.create) documentation
# * [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#contentmanager)
#  * Adds support for `Workforce Version 2 Projects` to [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.clone_items)
#  * Adds [`generate()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.generate) method to create features from `CSV`, `shapefile`, `GPX`, and `GeoJSON` files
# * [`Group`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Group)
#  * Adds [`search()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Group.search) method for searching group content
#  * [`add_users()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Group.add_users)
#  * Adds [`delete_group_thumbnail()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Group.download_thumbnail) method
# * [`ResourceManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ResourceManager)
#  * Adds [`export()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ResourceManager.export) method
#  * Adds `access` parameter to [`add()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ResourceManager.add) method
#  * Updates [`remove()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ResourceManager.remove) `file` parameter so if not specifed all `dependencies` are removed
#  * Adds check to ensure [`validate()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.DatastoreManager.validate) returns `Boolean` result
# * [`DataStore`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#datastore)
#  * Adds check to ensure [`regenerate()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Datastore.regenerate) returns `Boolean` result

# %% [markdown]
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#)
# * Adds [`generate_report()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#arcgis.gis.admin.AGOLUsageReports.generage_report) method to [`AGOLUsageReports`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#agolusagereports) for organizational usage monitoring

# %% [markdown]
#  * allows publisher role the ability to obtain server ID information needed for datastore registration (**`Enterprise 10.9`**)
# * [`ReportManager`]()
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/)
# * Adds [`properties`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ServerManager.properties) to [`ServerManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#servermanager)
# * Adds [`Extension`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#extension) documentation to APi Reference
#  * Adds code example to [`create()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.create)
#  * Adds code example to [`quick_report()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.quick_report)

# %% [markdown]
# * Adds environment variables:
#  * `union_dimension`
#  * `match_variables`#### [`arcgis.env`](https://developers.arcgis.com/python/api-reference/arcgis.env/)

# %% [markdown]
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/)
# * [`FeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer)
#  * Adds note to [`edit_features()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.edit_features) to use only for small batches of edits
#  * Adds [`query_analytics()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.query_analytics) method for **ArcGIS Online Hosted Layers only** (`ArcGIS Enterprise` support forthcoming)
# * [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor)
#  * Adds [`from_feather()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_feather) method for [`feather format files`](https://arrow.apache.org/docs/python/feather/#feather-file-format)
# * [`FeatureLayerCollection`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayercollection)
#  * Adds code example to [`extract_changes()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayerCollection.extract_changes) API Reference
# * Adds `return_edits` parameter to [`ValidationManager.update_error()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._validation.ValidationManager.update_error)

# %% [markdown]
#     * Adds documentation
#     * Adds parameters:
#      * `bin_type`
#      * `bin_size`
#      * `bin_size_unit`
#     * Adds parameters:
#      * `param_as_input`#### [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/)
#  * [`analyze_patterns`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns/#)
#   * [`find_point_clusters()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns/#find-point-clusters)
#  * [`summarize_data`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#)
#   * [`summarize_within()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#summarize-within)
#  * [`manage_data`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#)
#   * [`run_python_script()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#run-python-script) for `Enterprise 10.9`

# %% [markdown]
#    * adds `moments` parameter
#    * adds parameter table
#  * Adds methods:
# #### [`arcgis.features.managers`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/)
# * [`Version`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#version)
#  * [`differences()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._version.Version.differences) method
#  * Adds [`restore()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._version.Version.restore) method
# * [`AttachmentManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.AttachmentManager)
# * [`ParcelFabricManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._parcel.ParcelFabricManager)
#    * [`analyze_least_squares_adjustment()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._parcel.ParcelFabricManager.analyze_least_squares_adjustment)
#    * [`apply_least_squares_adjustment()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._parcel.ParcelFabricManager.apply_least_squares_adjustment)

# %% [markdown]
#  * Adds new properties:
#    * `RAT`
#  * Adds new methods:
#    * `get_colormap()`
#    * `set_colormap()`
#    * `get_statistics()`
#    * `set_statistics()`
#    * `get_histograms()`
#    * `set_histograms()`
#    * `append_slices()`
#    * `set_variable_attributes()`
#    * `summarize()`
#  * Raises errors for `properties` and `methods` not supported by `TilesOnly` layers
#    * Adds parameters:
#      * `rendering_rule`
#      * `variable`
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/)
# * [`Raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#raster)
# * [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer)
#  * Adds [`tiles_only`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.tiles) property
#  * Adds [`render_tilesonly_layer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.render_tilesonly_layer) method
#  * [`colormap()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.colormap)
#  * Adds [`get_histograms()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.get_histograms) method
#  * Adds [`statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.statistics) method
# * Adds [`RasterInfo`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#rasterinfo) Class

# %% [markdown]
# * Enhances API to utilize the hosted imagery and raster analysis capabilities available with the June 2020 ArcGIS Online
# * Adds `tiles_only` keyword argument to functions
#  * Adds new parameter:
#   * `delete_transpose` (*Parameter available in ArcGIS Image Server 10.9 or higher*)
#  * Adds new parameter:
#   * `percentile_interpolation_type`(*Parameter available in ArcGIS Image Server 10.9 or higher*)
# * Enhanced the following functions to accept local datasets to create hosted imagery layers
#  * Adds `input_barriers` parameter (*requires in ArcGIS Image Server 10.9 and higher*)
#  * Adds `create_network_paths` parameter (*requires in ArcGIS Image Server 10.9 and higher*)#### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/)
# * [`build_multidimensional_transpose()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#arcgis.raster.analytics.build_multidimensional_transpose)
# * [`summarize_raster_within()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#summarize-raster-within)
#  * [`create_image_collection()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#create-image-collection)
#  * [`copy_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#copy-raster)
# * Adds [`merge_multidimensional_rasters()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#merge-multidimensional-rasters) function (*requires ArcGIS Image Server 10.9 or higher*)
# * [`calculate_density()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#calculate-density)
# * [`optimal_path_as_line()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#optimal-path-as-line)

# %% [markdown]
# * Adds new functions:
#  * detect_change_using_change_analysis_raster
#  * trend_to_rgb
#  * apparent_reflectance
#  * buffered
#  * rasterize_features
#  * reproject
#  * heat_index
#  * wind_chill
#  * aspect_slope
#  * contour
#  * compute_change
#  * aggregate
#  * bai
#  * nbr
#  * ndbi
#  * ndmi
#  * ndsi
#  * mndwi
#  * Adds new options for method:
#    * BAI
#    * NBR
#    * NDBI
#    * NDMI
#    * NDSI
#    * MNDWI
#  * Adds options for `regression_type` parameter:
#    * `MANN-KENDALL`
#    * `SEASONAL-KENDALL`
#  * Adds new parameter:
#    * `seasonal_period`
#  * Adds new options for `stat_type`:
#    * Median
#    * Majority
#    * Minority
#  * Adds `cellsize_type` parameter
#  * Adds new parameters:
#    * `tolerance`
#    * `dem`#### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/)
# * [`band_arithmetic()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/?highlight=band_arithmetic#band-arithmetic)
# * [`generate_trend()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#generate-trend)
# * [`focal_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#focal-statistics)
# * [`composite_band()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/?highlight=band_arithmetic#composite-band)
# * [`geometric()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/?highlight=band_arithmetic#geometric)

# %% [markdown]
# * Adds new functions:
#  * Adds new parameter:
#   * `percentile_interpolation_type` (*Parameter available in ArcGIS Image Server 10.9 or higher*)
#  * Adds `in_barriers` parameter (*Parameter available in ArcGIS Image Server 10.9 and higher*)#### [`arcgis.raster.functions.gbl`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/)
#  * [`boundary_clean()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#boundary-clean) (*Parameter available in ArcGIS Image Server 10.9 or higher*)
# * [`zonal_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#arcgis.raster.functions.gbl.zonal_statistics)
# * [`kernel_density()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#kernel-density)

# %% [markdown]
#  * Enhanced module to work with ArcGIS Online#### [`argis.raster.functions.RFT`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.RFT/)

# %% [markdown]
#      * `time_step_interval`
#      * `time_step_interval_unit`
#      * `time_step_repeat_interval`
#      * `time_step_repeat_interval_unit`
#      * `time_step_reference`#### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/)
#  * [`summarize_data`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/) submodule
#    * Adds time stepping parameters to [`summarize_attributes()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#summarize-attributes) for `10.9+` releases

# %% [markdown]
#  * Adds missing api reference documentation#### [`arcgis.geometry.functions`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.functions/#)

# %% [markdown]
# * Adds new classes
#  * Adds support for setting a `basemap` to the following layer types: (See [`WebMap Specification operationalLayers`](https://developers.arcgis.com/web-map-specification/objects/operationalLayers/)):
#    * `ImageServiceVectorLayer`
#    * `VectorTileLayer`
#    * `WebTiledLayer`
#    * `WMSLayer`
# #### [`arcgis.mapping`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/)
#  * [`MapServiceLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#mapservicelayer)
#  * [`MapFeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#mapfeaturelayer)
#  * [`MapRasterLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#maprasterlayer)
#  * [`MapTable`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#maptable)
# * Adds support for polygons to the `extent` parameter of [`OfflineMapAreaManager.create()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.OfflineMapAreaManager.create)
# * [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#webmap)
#  * Adds [`get_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.get_layer) method
#  * Adds [`get_table()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.get_table) method
#  * Adds ability to allow user-defined extent in [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.save)

# %% [markdown]
#  * Adds `data` parameter to allow plotting from a string or local file#### [`arcgis.mapping.ogc`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#)
# * [`GeoJSONLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#geojsonlayer)

# %% [markdown]
#  * Addresses many browser connection errors with the `gis.map()` functionality
#  * Example: BUG-000124898 - IWA authenticated portals returning authentication error
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/)
# * Updates [`MapView`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) to use `JavaScript 4.17`
# * Adds note to [`MapView`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) documentation clarifying proper configuration to avoid various `CORS` errors
# * Changes default basemap for anonymous access to the [`OSM Basemap`](https://esri.maps.arcgis.com/apps/View/index/?appid=d6b18a2e774c4959ba855f6ac90952a2)
# * Adds [`embed()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.embed) function to enable a live, interactive map widget in exported HTML notebooks
# * Adds [`map widget`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) support to [`JupyterLab`](https://jupyterlab.readthedocs.io/en/stable/) 2.x releases
# * Adds [`map widget`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) to extensions that can be installed with [`JupyterLab Extension Manager`](https://jupyterlab.readthedocs.io/en/stable/user/extensions/#using-the-extension-manager)
# * Adds support for visualizing [`SceneLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#scenelayer) types
#  * [`PointCloudLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#pointcloudlayer)
#  * [`Point3DLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#point3dlayer)
#  * [`Object3DLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#object3dlayer)
#  * [`IntegratedMeshLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#integratedmeshlayer)
#  * [`BuildingLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#buildinglayer)

# %% [markdown]
# * Adds new `url` builders:
#  * Adds logic enforcing layer and table order of feature service when created
# #### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps/)
# * Adds new [`Dashboard`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard/) submodule
#  * [`build_workforce_url`](https://developers.arcgis.com/python/api-reference/arcgis.apps/#build-workforce-url)
#  * [`bulld_field_maps_url`](https://developers.arcgis.com/python/api-reference/arcgis.apps/#build-field-maps-url)
# * Adds `updateFeature` support as option for `actions` parameter in [`build_collector_url`](https://developers.arcgis.com/python/api-reference/arcgis.apps/#build-collector-url)
# * [`Workforce`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/)
#  * Adds logic to enforce [`integrations`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce.managers/#arcgis.apps.workforce.managers.AssignmentIntegrationManager.add) with the same id both have assignment types
#  * Adds validation logic to the [`Assignment`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/#assignment) class for `priority` parameter

# %% [markdown]
# * New Table of Contents structure: (new classes and functions at 1.8.3 listed here)
#      * [`Inference Only Models`](https://developers.arcgis.com/python/api-reference/arcgis-learn-text-module#inference-only-models) submodule
# * Adds support for [`.dlpk`](https://pro.arcgis.com/en/pro-app/help/sharing/overview/share-a-deep-learning-model-package.htm#) format to the `from_model()` function in all models
# * Adds support for `Meta Raster Format (MRF)` tiles
# * Adds driver-related `Pytorch` along with `torch.cuda.is_available()` when deciding between using `GPU` and `CPU`
# * Adds `torch.cuda.get_device_capability()` check
# * Adds `save_inference_file` parameter to `save()` method of models
# * Adds ability to show intermediate results on Tensorboard during training for:
#  * `FeatureClassifier`
#  * `Single Shot Detector`
#  * `Retinanet`
#  * `UNetClassifier`
#  * `SuperResolution`
#  * `FasterRCNN`
#  * `MaskRCNN`
#  * `PSPNetClassifier`
#  * `DeepLab`
#  * `MultiTaskRoadExtractor`
# * Adds ability to override `ImageHeight` saved in `UnetClassifier`, `MaskRCNN` and `FasterRCNN` models to enable inferencing on larger image chips if GPU model allows
#  - Adds normalization in labels
#  - Adds denormalization while inferencing
#  - Adds time spent per epoch
#  - Adds extension to support transformer models
#  - adds default transformations
#  * Adds multispectrals support when `tensorboard=True`
#  * Adds support for `kwargs` parameter
#   * `Clustering Models`
#   * `Gaussian Mixture Models`
#   * `Novelty and Outlier Detection Models`
#  * Adds methods:
#    * renames `output_raster_folder_path` to `output_raster_path`
#    * renames `predict_features` to `prediction_type`
#   * Adds multiband raster support
#  * Adds multi-label support for training
#  * Adds note to `oversample` parameter explaining supported datasets
#    * `compute_metrics`
#    * `save_optimizer`
#    * `save_inference_file`
# * Adds [`PointRend`](https://github.com/facebookresearch/detectron2/tree/master/projects/PointRend) to improve performance for:
# * [`PointCNN`]()
#  * Updates how `transforms` are applied on point cloud so both original data and trasformed data passed
#  * Updates dependencies in [`SciPy`](https://www.scipy.org/) and removes dependencies on `transform3d` and `plotly-orca`
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)
#  * [`Data Preparation Methods`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#data-preparation-methods)
#    * [`prepare_textdata()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-textdata)
#  * [`Object Classification Methods`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-classification-methods)
#  * [`Object Detection Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-detection-models)
#  * [`Pixel Classification Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pixel-classification-models)
#    * [`HEDEdgeDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#hededgedetector)
#    * [`BDCNEdgeDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#bdcnedgedetector)
#    * [`MultiTaskRoadExtractor`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#multitaskroadextractor)
#    * [`ChangeDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#changedetector)
#  * [`Image Translation Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#image-translation-models)
#    * [`ImageCaptioner`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#imagecaptioner)
#    * [`Pix2Pix`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pix2pix)
#    * [`CycleGAN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#cyclegan)
#  * [`3D Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#d-models)
#  * [`Scanned Maps`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#scanned-maps)
#    * [`ScannedMapDigitizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#scannedmapdigitizer)
#  * [`Tabular and Feature Data Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#tabular-and-feature-data-models)
#    * [`TimeSeriesModel`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#timeseriesmodel)
#  * [`Unstructured Text Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unstructured-text-models)
#    * [`arcgis.learn.text`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis-learn-text-module) submodule
#      * [`TextClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn#argis.learn.text/#textclassifier)
#      * [`SequenceToSequence`](https://developers.arcgis.com/python/api-reference/arcgis.learn#argis.learn.text/#sequencetosequence)
#        * [`FillMask`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#fillmask)
#        * [`QuestionAnswering`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#questionanswering)
#        * [`TextGenerator`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#textgenerator)
#        * [`TextSummarizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#textsummarizer)
#        * [`TextTranslator`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#texttranslator)
#        * [`ZeroShotClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#zeroshotclassifier)
#  * [`Inferencing Methods (Image Server)`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#inferencing-methods-image-server)
#    * [`compute_accuracy_for_object_detection()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#computer-accuracy-for-object-detection) (*Requires ArcGIS Image Server 10.9 or higher*)
#  * [`Model Management`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#model-management)
#    * [`ModelExtension`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#modelextension)
# * Adds message to install `gdal` if using multispectral data with [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data)
# * Adds documentation to the `resize_to` parameter for [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data)
# * Adds `dice coefficient` and `soft dice loss` for multiclass [`UNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier), [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier), and [`Deeplab`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#deeplab) models
# * [`SuperResolution`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#superresolution)
#  - Adds [`compute_metrics()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.SuperResolution.compute_metrics) method for accuracy metrics on validation sets
#  - Adds [`supported_datasets`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#SuperResolution.supported_datasets) property
# * [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#entityrecognizer)
#  - Adds ability to save `model_metric/`
#  - Adds [`f1_score()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.f1_score) description to API reference
# * [`MaskRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#maskrcnn)
# * [`FasterRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#fasterrcnn)
#  * Adds [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FasterRCNN.predict) method
#  * Adds [`predict_video()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FasterRCNN.predict_video)
# * [`MLModel`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#mlmodel)
#  * Adds support for [`unsupervised learning`](https://scikit-learn.org/stable/unsupervised_learning/)
#   * [`decision_function()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.decision_function)
#   * [`feature_importances()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.feature_importances)
#   * [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.predict)
# * [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier)
#  * Adds parameters to [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.save):
#  * Adds note to [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.predict) that it only supports RGB images
#  * [`DeepLab`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#deeplab)
#  * [`PSPNetClassifer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier)
#  * [`MaskRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#maskrcnn)
#  * Adds ability to preserve classcodes in file when using [`predict_las()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.predict_las)

# %% [markdown]
# ## Fixes

# %% [markdown]
# ### [Guides](https://developers.arcgis.com/python/guide/)
# * Working with the Spatially Enabled DataFrame
#  * Updates [Visualizing Spatial Data](https://developers.arcgis.com/python/guide/visualizing-data-with-the-spatially-enabled-dataframe/)
# * Managing ArcGIS Applications
#  * Updates [Managing Workforce projects](https://developers.arcgis.com/python/guide/managing-workforce-projects/)
# * Deep Learning with ArcGIS
#  * Updates `fastai` link with [Object Detection Workflow with `arcgis.learn`](https://developers.arcgis.com/python/guide/object-detection-and-tracking-on-videos/)
#  * Updates to [Working with Multispectral Data](https://developers.arcgis.com/python/guide/working-with-multispectral-data/)
#  * Updates to [Point Cloud Segmentation using PointCNN](https://developers.arcgis.com/python/guide/point-cloud-segmentation-using-pointcnn) * Updates to [Named Entity Extraction Workflow with [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)](https://developers.arcgis.com/python/guide/how-named-entity-recognition-works)

# %% [markdown]
# ### [Samples](https://developers.arcgis.com/python/sample-notebooks/)
# * Power Users/Developers
#  * Updates to various samples:
#    * [A dashboard to explore world population](https://developers.arcgis.com/python/sample-notebooks/population-exploration-dashboard/)
#    * [Using geoprocessing tools](https://developers.arcgis.com/python/sample-notebooks/using-geoprocessing-tools/)
#    * [Tour the World with Landsat Imagery and Raster Functions](https://developers.arcgis.com/python/sample-notebooks/tour-the-world-with-landsat-imagery-and-raster-functions/)
#    * [Raster Analytics Dashboard](https://developers.arcgis.com/python/sample-notebooks/jupyter-dashboard-for-raster-analytics/)
#    * [Building a change detection app using Jupyter Dashboard](https://developers.arcgis.com/python/sample-notebooks/building-a-change-detection-app-using-jupyter-dashboard/)
# * GIS analysts and data scientists
#  * Enhances `Deep Learning Samples` by providing training data
#  * Fixes typos in `sdf` field names for [Data Summarization - Construction permits near Washington DC, part 2/2](https://developers.arcgis.com/python/sample-notebooks/analyze-patterns-in-construction-permits-part2/)
#  * Adds data for [Finding a New Home](https://developers.arcgis.com/python/sample-notebooks/finding-a-new-home/)
#  * [Plant species identification using a TensorFlow-Lite model within mobile devices](https://developers.arcgis.com/python/sample-notebooks/train-a-tensorflow-lite-model-for-identifying-plant-species/)
#    * Updates explanations
#    * Removes single band imagery
#  * Updates paths for data in [Vehicle detection and tracking using deep learning](https://developers.arcgis.com/python/sample-notebooks/vehicle-detection-and-tracking/)
#  * Updates text for [
# Chennai Floods 2015–A Geographic Analysis](https://developers.arcgis.com/python/sample-notebooks/chennai-floods-analysis/) to remove uninitelligble rendering
#  * [Automate Road Surface Investigation Using Deep Learning](https://developers.arcgis.com/python/sample-notebooks/automate-road-surface-investigation-using-deep-learning/)
#    * Adds missing inference data to the `predict` and `predict_video` functions in
#    * Removes hard-coded `lr_find()` value
#  * [Information extraction from Madison city crime incident reports using Deep Learning](https://developers.arcgis.com/python/sample-notebooks/information-extraction-from-madison-city-crime-incident-reports-using-deep-learning/)
#    * Fixes Table of Contents and hyperlinks
#    * Adds Save and load trained models section
#    * Updates Prerequisites and imports
#  * Updates model training data in [Automate Building Footprint Extraction using Deep learning](https://developers.arcgis.com/python/sample-notebooks/automate-building-footprint-extraction-using-instance-segmentation/)
#  * Updates to organization type and data paths in [Land Cover Classification using Satellite Imagery and Deep Learning](https://developers.arcgis.com/python/sample-notebooks/land-cover-classification-using-unet/)
#  * [Land cover classification using sparse training data](https://developers.arcgis.com/python/sample-notebooks/land-cover-classification-using-sparse-training-data/)
#    * Updates no data explanations
#    * Removes data mapping
#    * Changed Meta Data Format when exporting training data to `Export Tiles`
#    * Fixes typo for output type  * [Increase image resolution using [`SuperResolution`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#superresolution)](https://developers.arcgis.com/python/sample-notebooks/increase-image-resolution-using-superresolution)

# %% [markdown]
# * Fixes authentication error with `Python 3.7` and `Notebook Server`
# * Fixes issue with ArcGIS online comments with certain unicode characters not getting returned properly
# * Fixes `deprecation warnings` when import API in `Notebook Server`
# * Fixes token errors with public [`Geometry`](https://developers.arcgis.com/rest/services-reference/geometry-service.htm) and [`Geoprocessing`](https://developers.arcgis.com/rest/services-reference/gp-service.htm) services affecting API and `Notebook Server`
# * Fixes BUG-000133849 - `data` resource is missing when `KML` or `KMZ` files are added to ArcGIS Online
# * [`GroupMigrationManger`]()
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis)
# * Fixes parameter names in [`PortalDataStore.publish()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis._impl._datastores.PortalDataStore.publish) code example for the `config` parameter
# * Clarifies documentation for `storageUsage` parameter of [`User`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#user) objects
# * Fixes error with [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.clone_items) on [`Survey`](https://developers.arcgis.com/python/api-reference/arcgis.apps.survey123/#survey) items
# * [`Item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#item)
#  * Fixes documentation error in parameter table for [`reassign_to()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.reassign_to)
# * [`UserManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#usermanager)
#  * Fixes `KeyError: UserTypes` error with [`create()`]() when [`user_settings`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.UserManager.user_settings) configured improperly
# * [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#contentmanager)
#  * Fixes BUG-000133739 - [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.clone_items) on hosted feature layer views returns `JSONDecodeError: Expecting value: line 1 column 1 (char 0)` error
#  * Fixes to [`inspect()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.GroupMigrationManager.inspect) and [`load()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.GroupMigrationManager.load) not recoginizing new items

# %% [markdown]
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#)
# * Fixes error returning `ArcGIS Online` [`history()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#arcgis.gis.admin.AGOLAdminManager.history) when return type is a `DataFrame`

# %% [markdown]
# * Fixes issue where a "/" added to the server admin url creates invalid connection
# * Fixes issue with mangled `URL` when connecting to unfederated servers URL
# * [`ReportManager`]()
#    * `queries`
#    * `from_value`
#    * `to_value`
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/)
# * Fixes issue when creating [`Server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Server) object without a Portal connection on a Federated Server
#   * **NOTE:** The [`ServiceDirectory`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#module-arcgis.gis.server.catalog) [`list()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.catalog.ServicesDirectory.list) or [`find()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.catalog.ServicesDirectory.find) methods should be used to create [`Server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Server) objects
#  * BUG-000133053 [`list()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.list) method returns error if a saved report created from ArcGIS Server manager exists on server
#  * Fixes issue when [`create()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.create) fails if existing reports named as integers
#  * Fixes errors in [`create()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.create) documentation for parameters:
#  * Fixes BUG-000134098 unexpected keyword argument `from_value` error in [`quick_report()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.quick_report)
#  * Removes incorrect option from `since` parameter documentation for [`quick_report()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ReportManager.quick_report)

# %% [markdown]
#  * Fixes performance issues when reading geometries
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/)
# * [`FeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayer)
#  * Fixes issue when [`query()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.query) result is `esriFieldTypeFloat`
#  * Fixes issue with [`query(as_df=True)`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.query) results on `Hosted Feature Layer` when specifying `out_fields` and `DateTime` fields are present
# * [`FeatureLayerCollection`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayercollection)
#  * Fixes [`extract_changes()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayerCollection.extract_changes) returning no values
# * [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor)
#  * Fixes issue when using [`enrich()`](https://developers.arcgis.com/python/api-reference/arcgis.geoenrichment/#enrich) with `sedf` with more than 100 records
#  * Fixes bug with [`to_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featureclass) not supporting memory workspaces
#  * Fixes [`from_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_layer) method failing for [`tables`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#table)
#  * Fixes error with [`set_geometry()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.set_geometry) not recognizing geometry columns if not named "SHAPE"
#  * Fixes [`plot()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.plot) errors on small or null geometries in environments with `ArcPy`
#  * Fixes [`buffer()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoSeriesAccessor.buffer) method failing on projected geometries
#  * Fixes [`to_table()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_table) issue with `CSV` files
# * [`FeatureSet`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featureset)
#  * Fixes [`from_geojson()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureSet.from_geojson) resulting in malformed ring data for polygons
#  * Fixes [`from_geojson()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureSet.from_geojson) failures on `MultiPolygons`

# %% [markdown]
#     * Fixes error when `output_name` parameter is a dictionary
#     * Fixes incorrect formatting in code example
#     * Fixes `extent_layer` parameter documentation so parameter is optional
#     * Fixes issue where polygon layer was required even though `bin_type`, `bin_size`, and `bin_size_unit` were specified
#     * Fixes incorrect format for `distances` parameter in documentation
# #### [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/)
#  * [`analyze_patterns`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns/#)
#   * Fixes [`find_point_clusters()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns/#find-point-clusters) documentation
#  * [`manage_data`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data/)
#   * [`extract_data()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data/#extract-data)
#   * [`dissolve_boundaries()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data/#dissolve-boundaries)
#   * [`generate_tesselation()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data/#generate-tessellation)
#  * [`summarize_data`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/)
#   * [`aggregate_points()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#aggregate-points)
#   * [`summarize_nearby()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#summarize-nearby)
#  * [`find_locations()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations/)
#   * Fixes failure when setting `distance band` and `distance_band_unit` parameters with [`find_hot_spots()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns/#find-hot-spots)
#   * Fixes failure when setting `distance band` and `distance_band_unit` parameters with [`find_outliers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns/#find-outliers)

# %% [markdown]
#   * Fixes BUG-000124231 - updating a feature layer from a CSV on `ArcGIS Enterprise` returns error message, `Job Failed.`#### [`arcgis.features.managers`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/)
# * [`SyncManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#syncmanager)
#  * Fixes error with [`sync_replicated_items()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.SyncManager.sync_replicated_items) failing to upload features if child is an `ArcGIS Enterprise` replica
# * [`AttachmentManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.AttachmentManager.update)
#  * Fixes issue with [`update()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.AttachmentManager.update) method not updating the attachment
# * [`FeatureLayerCollectionManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#featurelayercollectionmanager)
#  * Fixes [`create_view()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.create_view) to honor value for `extent` parameter
#  * Fixes code differences in [`overwrite()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.overwrite) so results match [`Item.publish(overwrite=True)`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.publish) in `ArcGIS Enterprise`

# %% [markdown]
# * [`ImageryLayer`]()
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/)
# * [`RasterCollection`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterCollection)
#  * Fixes errors with [`filter_by_calendar_range()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterCollection.filter_by_calendar_range) method
#  * Fixes [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.save) failure after using [`apply()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#apply) function on secured services

# %% [markdown]
# #### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#)
#  * Adds [`aggregate()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#aggregate) function

# %% [markdown]
# * Sets default values for optional parameters to `None` to rely on service defaults whether in `ArcGIS Online` and `ArcGIS Enterprise`#### [`arcgis.network`](https://developers.arcgis.com/python/api-reference/arcgis.network.toc/)

# %% [markdown]
# * Fixes situation when a failed tool creates an empty `Item` in the organization
#   * Fix incorrect parameter names to correct names:
#    * `time_boundary_ref`
#    * `time_boundary_unit`#### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/)
# * Fixes various tools to recognize the [`output_datastore`](https://developers.arcgis.com/python/api-reference/arcgis.env/#output-datastore) context parameter for writing output
# * Fixes [`aggregate_points()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#aggregate-points) to use `context` parameter
# * [`find_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#find-dwell-locations)
#  * [`find_dwell_locations()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#find-dwell-locations)

# %% [markdown]
# #### [`arcgis.geocoding`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/)
# * Updates [`suggest()`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#suggest) so `location` parameteris optional

# %% [markdown]
# * Fixes issue with various functions ignoring `inplace` paramter default value
# * Fixes issue with various functions not returning the `spatialReference` with output
# #### [`arcgis.geometry`](https://developers.arcgis.com/python/api-reference/arcgis.geometry/#)
# * Fixes issue with [`Polygon`](https://developers.arcgis.com/python/api-reference/arcgis.geometry/#polygon) failing if order of geometries used is not correct for EsriJSON format

# %% [markdown]
# * Fixes BUG-000131799 - import_tiles() returns error:"'Response' object is not subscriptable" because of improper url construction
# #### [`arcgis.mapping`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/)
# * Fixes error when `extent` parameter for [`OfflineMapAreaManager.create()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.OfflineMapAreaManager.create) is a `bookmark` or `dictionary`
# * [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#webmap)
#  * Fixes `AttributeError: layerType` error when calling [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.save)
#  * Fixes error on [`save()`]((https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.save)) if `WebMap` object had a [`FeatureLayerColletion`]() added with [`add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.add_layer)
# * Fixes issue with [`add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.add_layer) where only `layers` are added from an an [`Item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#item) or [`FeatureLayerCollection`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayercollection) that has both layers and tables
# * Fixes issue with [`add_table()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.add_table) trying to get a renderer when adding
# * Fixes BUG-000131725 - complex symbology is not preserved for `Map Service` added using the [`add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.add_layer) function
# * Fixes issue with [`zoom_to_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.zoom_to_layer) function failing to display layer if called before map has fully loaded

# %% [markdown]
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/)
# * Fixes [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.save) and [`update()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.update) methods to manage `typeKeywords` for offline map usage
# * Fixes [`add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.add_layer) error when adding a `raster` layer from `MapService`
# * Fixes error when adding `WMS` layers to `map widget` with [`add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.add_layer)
# * Fixes drawing error with local [`Raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#raster) objects
# * Fixes bug with [`add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.add_layer) with either local [`Raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#raster) or [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer) as input

# %% [markdown]
# #### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps/)
# * Updates [`workforce module`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/) to account for Version 2 schema changes

# %% [markdown]
# * Disables saving optimizer by default (default value of `save_optimizer` parameter `False` in models
# * Numerous documentation enhancements
# * Fixes `fit()` methods on multiple models when using `tensorboard=True`
# * Removes unnecessary warning messages when debugging is set
#  * Fixes warning messages when deciding between GPU or CPU
#  - Fixes [`prepare_data`]() issue when not creating labels when called without downsampling_factor
#  - fixes issue with default transforms causing prediction errors
#  - fixes error when image data format is `tiff`
#  - fixes `chip_size` causing artifacts while inferencing
# * Fixes errors when `gdal` was not handling non-contiguous class segementation
#  * Fixes issues with large loss values during model training
#  * Fixes per epoch metric calculation bug
#  * Fixes issue with incorrect exceptions raised when object craeted with no data
#  * Fixes class weights not used even after specifying `class_balancing=True`
#  * Fixes class weights not matching number of classes when data has been exported with one class having pixel value 0
#  * Fixes `NameError` when intializing with `use_unet` and `unet_aux_loss` both set to True
#  * Fixes class weights not used even after specifying `class_balancing=True`
#  * Fixes class weights not matching number of classes when data has been exported with one class having pixel value 0
#  * Fixes class weights not used even after specifying `class_balancing=True`
#  * Fixes class weights not matching number of classes when data has been exported with one class having pixel value 0
#  * Fixes situation with incorrect labels when multiband data is exported
# * [`RetinaNet`]()
#  * Fixes to auto-detection routines to determine CPU or GPU hardware available
#  * Fixes issues with `las` and `h5` files remaining open after using
#  * Multiple fixes to documentation
#  * Fixes errors when initializing with `mobilnet_v2` or `densenet` backbones
# * Fixes issue where saving checkpoint was not using the most apt value of validation loss when `early_stopping` is set to `true`
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)
# * Fixes bug with [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) failing with `Multispectral` data when `gdal` is not installed
# * Fixes issue where classcodes are not preserved in output raster when training data has non-contiguous classcode labels for [`Pixel Classification`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pixel-classfication-models) models
# * Fixes issue with inferencing when [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) `dataset_type` parameter is `ChangeDetection` and training data is multispectral
# * [`detect_objects()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#detect-objects)
# * [`SuperResolution`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#superresolution)
# * [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#entityrecognizer)
#  * Fixes [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.lr_find) to run for at least one full epoch per learning rate
#  * Fixes issue with [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.lr_find) output when data prepared with `batch_size` of 2
#  * Fixes text column to be first column in [`show_batch()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.show_batch)
# * [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier)
#  * Fixes issue with [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.fit) not displaying results after training with multipsectral data
#  * Fixes issues with [`show_results()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.show_results) failing with smaller validation datasets
#  * Fixes failures of [`plot_hard_examples()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.plot_hard_examples) with multilabel model
#  * Fixes errors when running [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.fit) if `oversample=True`
#  * Fixes issues with [`plot_losses()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.plot_losses)
# * [`UnetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier)
#  * Fixes missing model type information from output of [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.UnetClassifier.save)
#  * Fixes `ValueError` with [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.UnetClassifier.lr_find) and [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.UnetClassifier.fit)
#  * Fixes [`show_results()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.UnetClassifier.show_results) tesnor shape error
#  * Fixes inconsistent [`accuracy()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.UnetClassifier.accuracy) results between fitting and loading
# * [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier)
#  * Fixes missing model type information from output of [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PSPNetClassifier.save)
#  * Fixes inconsistent [`accuracy()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PSPNetClassifier.accuracy) results between fitting and loading
#  * Fixes `ValueError` with [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PSPNetClassifier.lr_find) and [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PSPNetClassifier.fit)
#  * Fixes error with [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PSPNetClassifier.lr_find) and `VGG` backbones if model created with `use_unet=True`
#  * Fixes errors in [`fit()`](ttps://developers.arcgis.com/python/api-reference/arcgis.learn/#arcgis.learn.PSPNetClassifier.fit) on object created wtih `VGG` backbone and `pointrend=True`
# * [`DeepLab`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#deeplab)
#  * Fixes inconsistent [`accuracy()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.DeepLab.accuracy) results between fitting and loading
# * [`MaskRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#maskrcnn)
# * [`FasterRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn/#fasterrcnn)
#  * Fixes [`show_results()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FasterRCNN.show_results) failing with multispectral data
#  * Fixes issue with [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FasterRCNN.save) raising exception instead of returning no boxes when using default parameters
#  * Fixes [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FasterRCNN.fit) method when `tensorboard=True`
# * [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN)
#  * Fixes [`predict_las()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.predict_las) failing when output folder is not empty or has files with `pred` in name or `.las` extension
#  * Fixes issue [`predict_las()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.predict_las) failing if `.las` files have a period in the filename
# * [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector)
#  * Fixes [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.SingleShotDetector.predict) `TypeError` when using multispectral data
#  * Fixes errows with [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.SingleShotDetector.predict) when using multipsectral data and `visualize=True`
# * [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#entityrecognizer)
#  * Fixes issues with incorrect exceptions raised caling [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.fit) or [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.lr_find) if object initialized without data
# * Fixes issue where the HTML file with model metrices (`model_metrices/`) not getting saved when training `UnetClassifer`, `PSPNetClassifier`, `DeepLab`, `SingelShotDetector` and `RetinaNet` models
