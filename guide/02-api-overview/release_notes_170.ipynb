# %% [markdown]
# # What's new in version 1.7
#
# ## New
#
#
# ### Guides
#
# #### [Imagery and raster analysis](https://developers.arcgis.com/python/guide/)
# * [Orthomapping (part 1) - creating image collections](https://dv-v170-pyapi-preview-dev.developers.arcgis.com/python/guide/orthomapping-guide-1/)
# * [Orthomapping (part 2) - generating elevation models](https://dv-v170-pyapi-preview-dev.developers.arcgis.com/python/guide/orthomapping-guide-2/)
# * [Orthomapping (part 3) - managing image collections](https://dv-v170-pyapi-preview-dev.developers.arcgis.com/python/guide/orthomapping-guide-3/)
#
# #### [Deep Learning with ArcGIS](https://developers.arcgis.com/python/guide/)
# * [How does feature categorization work](https://developers.arcgis.com/python/guide/how-feature-categorization-works/)
# * [Categorizing features using arcgis.learn](https://developers.arcgis.com/python/guide/feature-categorization/)
#
# ### Samples
#
# * [Pawnee Fire analysis](https://developers.arcgis.com/python/sample-notebooks/wildfire-analysis-using-sentinel-2-imagery/)
# * [Finding grazing allotments](https://developers.arcgis.com/python/sample-notebooks/finding-grazing-allotments/)
# * [Extracting building footprints from drone data](https://developers.arcgis.com/python/sample-notebooks/extracting-building-footprints-from-drone-data/)
# * [Detecting super blooms using image classification](https://developers.arcgis.com/python/sample-notebooks/detect-super-blooms-using-satellite-image-classification/)
# * [Assessing building damage using feature classification](https://developers.arcgis.com/python/sample-notebooks/feature-categorization-using-satellite-imagery-and-deep-learning/)
# * [Analyzing New York City growth factors](https://developers.arcgis.com/python/sample-notebooks/analyzing-growth-factors-of-airbnb-properties-in-new-york-city/)
#
# ### Module Changes
#
#
#
# * Adds manager classes:
#    * provides missing certificate management in ArcGIS Online
#
#
# * Adds analysis tools
#
#
# * New multidimensional functions:
# * New parameters:
# * Documentation improvements:
#
# * Adds the `process_as_multiband` option to:
# * New functions:
#
# * New functions:
# * Adds `in_barrier_data` parameter to:
#
# * Adds new [`network analysis`]() functions
#
# * Documentation improvements:
#   * Adds
#
#   * Enhances
#
#
#
# * New models:
# * Documentation improvements:
# * Adds support for full range of multispectral imagery
# * Adds support for visualizing training progress
# * Changes `lr` parameter to optional in `fit()` methods of models
# * Adds support for multispectral imagery to `Unet` type models for inferencing when using [`Classify Pixels using Deep Learning`](https://pro.arcgis.com/en/pro-app/tool-reference/image-analyst/classify-pixels-using-deep-learning.htm)
#
# ## Fixes
#
# ### Module Changes
#
# * Fixes issue where `from arcgis import *` fails with `AttributeError` regarding `find_centroids` or `summarize_center_and_dispersion`
# * Fixes issue with setting `group.protected = False` on a group whose `protected` property is already `False`
# * Improves messaging when trying to read a `File Geodatabase` with environment that does not contain `ArcPy` and `fiona` packages
# * Fixes known issues when using `PKI`
# * Fixes publising error with items of type `Compact Tile Package`
#
#
#
#
# * Fixes multiple functions to write output types
# * Fixes handling of the `travel_mode` input parameter for:
# * New parameters:
#
# * Fixes issue where a [`Raster Function Template`]() fails to dynamically render output when federated servers serve multiple server `functions`
#
#
#
#
#
# * Fixes issue when [`WebMap.save()`]() would not reproject data to correct spatial reference if the view when saved was outside the range
#
#
# * Adds ability to run `Geoprocessing tools` asynchronously with new [`GPJob`](https://developers.arcgis.com/python/api-reference/arcgis.geoprocessing/#gpjob) class. See `future` parameter in:
#  * [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#submodules) submodules
#  * [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#) module
#  * [`arcgis.network.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.network.analysis/) module
#  * [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/#submodules) submodules
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/)
#  * [`ProfileManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#profilemanager)
#  * [`CertificateManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#certificatemanager)
#  * [`InvitatationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#invitationmanager)
# * Adds support to [`add`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.add) a [`geopackage`](https://www.geopackage.org/) file
# * Adds `folder` parameter to [`import_data()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.import_data)
# * Adds `reset_by_email` parameter to [`user.reset()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.User.reset) to allow user to reset their accounts by email
# * Adds `replace_metadata` parameter to [`replace_service()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/?highlight=replace_service#arcgis.gis.ContentManager.replace_service)
# * Adds support for `hosted tile layers` and `hosted scene layers` to [`replace_service()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/?highlight=replace_service#arcgis.gis.ContentManager.replace_service) operation
# * Adds [`delete_thumbnail()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.User.delete-thumbnail) to `user` class
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/)
# * Adds [`hardware`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Machine.hardware) property to [`Machine`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#machine) class
# * Adds [`ItemInformationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.ItemInformationManager) to for administration
# * Adds new [`federate_data_item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.DataStoreManager.federate_data_item). See [`Add To Server`](https://developers.arcgis.com/rest/users-groups-and-items/add-to-server.htm)
# * Adds [`change_provider()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Service.change_provider) method to [`Service`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Service)
# * Adds [`synchronize()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Machine.synchronize) method to [`Machine`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#machine) class
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/)
#  * [`generate_tesselation`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data/#arcgis.features.manage_data.generate_tesselation) analysis tool
#  * [`create_route_layers`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data/#arcgis.features.manage_data.create_route_layers)
# * Adds `spatial_filter` parameter on [`Spatially Enabled Dataframe.from_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_featureclass) method
# * Adds missing `in_sr` parameter to [`extract_changes`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/?highlight=extract_changes#arcgis.features.FeatureLayerCollection.extract_changes) documentation
# * Adds `return_delete_results` parameter to [`delete_features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.delete_features) method
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/)
# * [`ImageryLayer.save()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.save) function
# * Adds a [`cache_manager`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.cache_manager) to [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer)
# #### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/)
#  * [`generate_multidimensional_anomaly()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#generate-multidimensional-anomaly)
#  * [`aggregate_multidimensional_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#aggregate-multidimensional-transpose)
#  * [`build_multidimensional_transpose()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#build-multi-dimensional-transpose)
#  * [`find_argument_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#find-argument-statistics)
#  * [`generate_trend_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#generate-trend-raster)
#  * [`predict_using_trend_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#predict-using-trend-raster)
#  * [`linear_spectral_unmixing()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#linear-spectral-unmixing)
#  * [`subset_multidimensional_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#subset-multidimensional-raster)
#   * [`costpath_as_polyline()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#costpath-as-polyline)
#  * Adds `statistics_type` parameter to [`flow_distance`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#flow-distance) function
#  * Adds and `context` parameter to [`raster analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/) functions to enable setting of function-specific processing
#  * Adds `destination_field` parameter to [`determine_travel_costpath_as_polyline`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#determine-travel-costpath-as-polyline)
#  * Adds `process_as_multidimensional` and `build_transpose` parameters to [`generate_raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#generate-raster) and [`copy_raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#copy-raster)
#  * [`add_image`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#add-image)
#  * [`delete_image_collection`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#delete-image-collection)
#  * [`create_image_collection`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#create-image-collection)
# * Adds ability to input a list to [`list_datastore_content()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#list-datastore-content)
# * Fixes error when using keyboard to cancel a [`raster analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/) geoprocessing job
# * Adds support for `item` as input to [`aggregate_multidimensional_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#)
# #### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/)
# * Adds the `WNDWI` predefined algorithm to [`band_arithmetic`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#band-arithmetic) function
# * Adds ability to accept `list` of integers or `string` as value for `band_indexes` parameter in [`band_arithmetic`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#band-arithmetic) function
#  * [`local()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#local)
#  * [`majority()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#majority)
#  * [`max()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#max)
#  * [`mean()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#mean)
#  * [`mid()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#mid)
#  * [`min()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#min)
#  * [`minority()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#minority)
#  * [`cellstats_range`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#cellstats-range)
#  * [`std()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#std)
#  * [`sum()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#sum)
#  * [`variety()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#variety)
#  * [`constant_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#constant-raster)
#  * [`random_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#random-raster)
# * Enhances [`focal_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#focal-statistics) and [`focatl_stats()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#focal-stats) documentation
# #### [`arcgis.raster.functions.gbl`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/)
#  * [`euclidian_back_direction`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#euclidean_back_direction)
#  * [`flow_length`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#flow_length)
#  * [`expand`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#expand)
#  * [`distance_allocation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-allocation)
#  * [`distance_accumulation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-accumulation)
#  * [`shrink`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#shrink)
#  * [`sink`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#sink)
#  * [`snap_pour_point`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#snap-pour-point)
#  * [`euclidean_allocation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#euclidean-allocation)
#  * [`euclidean_distance`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#euclidean-distance)
#  * [`euclidean_direction`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#euclidean-direction)
# * Adds `generate_out_back_direction_raster`, `in_barrier_data`, and `distance_method` parameters to [`calculate_distance`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#calculate-distance)
# * Adds default value of `MEAN` to [`zonal_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#zonal-statistics) `statistics_type` parameter
# * Adds `process_as_multidimensional` capability to [`zonal_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#zonal-statistics)
# #### [`arcgis.network.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.network.analysis/)
# * Adds `save_route_data` parameter to [`find-routes`](https://developers.arcgis.com/python/api-reference/arcgis.network.analysis/#find-routes) and [`find-closest-facilities`](https://developers.arcgis.com/python/api-reference/arcgis.network.analysis/#find-closest-facilities) tasks
#  and [`to_featurelayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featurelayer) methods
# * Improves `pixel_size` parameter documentation for appropriate [`ImageLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer) operations
# * Adds [`zoom_to_layer`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.zoom_to_layer) function
#  * Adds [`edit_vehicle_routing_problem`](https://developers.arcgis.com/python/api-reference/arcgis.network.analysis/#edit-vehicle-routing-problem)
# #### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/#module-arcgis.geoanalytics)
#    * [`find-point-clusters`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#find-point-clusters)
#    * [`calculate_fields`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#calculate-fields)
#    * [`aggregate_points`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#aggregate-points)
#    * [`build_multivariable_grid`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#build-multivariable-grid)
#    * [`find_hot_spots`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#find-hot-spots)
#    * [`create_buffers`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.use_proximity/#create-buffers)
#    * [`dissolve_boundaries`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#dissolve-boundaries)
#    * [`detect_incidents`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#detect-incidents)
#    * [`calculate_density()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#calculate-density)
#    * [`aggregate_points()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#aggregate-points)
#    * [`forest`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#forest)
#    * [`glr`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#glr)
#    * [`run_python_script`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#run-python-script)
#     * [`copy_to_data_store`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#copy-to-data-store)
#     * [`overlay_data`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#overlay-data)
#     * [`find_similiar_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#/find-similar-locations)
#     * [`enrich_from_grid`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.data_enrichment/#enrich-from-grid)
#     * [`merge_layers`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#merge-layers)
#     * [`join_features`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#join-features)
#     * [`summarize_within`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#summarize-within)
#     * [`summarize_attributes`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#summarize-attributes)
#     * [`reconstruct_tracks`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#reconstruct-tracks)
#     * [`geocode_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#geocode-locations)
# #### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps/)
#  * Adds new parameters to [`build_collector_url`](https://developers.arcgis.com/python/api-reference/arcgis.apps/#build-collector-url). See [`Deploy your map`](https://doc.arcgis.com/en/collector/ipad/help/deploy-map.htm#ESRI_SECTION1_F7DE2402BA8743E5BFC4A1241072960E) for parameter details.
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)
#  * [`RetinaNet`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#retinanet)
#  * [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#entityrecognizor)
#  * [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier)
#  * [`MaskRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#maskrcnn)
#  * [`export_training_data`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#export-training-data)
# * Adds option to [`UnetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier) to not predict the background class
# * Adds [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.SingleShotDetector.predict) and [`predict_video()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.SingleShotDetector.lr_find) methods to [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.SingleShotDetector.predict_video)
# * Adds [`plot_hard_examples()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.plot_confusion_matrix) function
# * Adds padding support to [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector)
# * Adds ability to train and inference on attachments in a `Feature Layer` using [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier)
# * Adds ability to train [`detect_objects`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#detect-objects) model with any dataset
# * Adds [`categorize_features`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.categorize_features) function and enhances to work with local rasters and feature classes
# * Adds Mobilenet backbone support to [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier) and [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector)
# * Adds [`SingleShotDetector.from_model()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FeatureClassifier.classify_features) method
# * Adds `resize_to` paramter to [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.prepare_data) function
# * Adds `from_model()` method to [`UnetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier)
# * Adds [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier) inferencing when using `ArcGIS Pro`
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/)
# * Corrects [`max_results`]() parameter documentation for the [`search()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.UserManager.search) method of [`UserManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#usermanager)
# * Fixes issue in `ArcGIS Online` that a `user` who does not own public data could not [`share()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.share) an [`Item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item) to group
# * Fixes error when returning a `Pandas dataframe` with [`item.usage(date_range='6m'`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.usage)
# * Fixes issue in [`ContentManager.add()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.add) if data contains multiple files
# * Fixes [`invite()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.UserManager.invite) method on ArcGIS Online `UserManager` instance to accept `email` parameter
# * Fixes issue with [`item.usage`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/?highlight=usage#arcgis.gis.Item.usage) failing on non-hosted layers in ArcGIS Online
# * Fixes [`advanced_search()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.advanced_search) method to properly return results based on `sort_field`
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/)
# * Fixes issue with [`ItemInformationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Service.iteminformation) to retrieve [`service`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#service) metadata
# * Fixes BUG-000112855 `AttributeError` thrown when trying to [`rename`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#arcgis.gis.server.Service.rename) service
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/)
# * Fixes error with `Spatially Enabled DataFrame` [`to_featureset()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featureset) method failing if DataFrame contains non-unique index
# * Improves ouput for [`Spatially Enabled DataFrame.to_featurecollection()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_feature_collection)
# * Fixes issue with `HeatMapRenderer` not honoring color breaks (See [`Spatially Enabled DataFrame.plot()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.plot)
# * Fixes `TypeError` when using [`FeatureLayerCollection.query_domains()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayerCollection.query_domains)
# * Improves [`FeatureLayer.query()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.query) performance with large result sets
# #### [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/)
# * Fixes issue where [`create_route_layers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/#create-route-layers) only returns a single layer from multiple result layers
# * Fixes error with [`find_nearest()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#find-nearest) when input is a `Feature Collection`
#  * [`find_nearest()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#find-nearest) improperly
#  * [`choose_best_facilities()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/##choose-best-facilities)
#  * [`connect_origins_to_destinations()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#connect-origins-to-destinations)
#  * [`create_drive_time_areas()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#create-drive-time-areas)
# * Fixes [`aggregate_points`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/#aggregate-points) failing when output is a `FeatureCollection`
#  * `route_shape` in [`connect_origins_to_destinations()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#connect-origins-to-destinations)
#  * `travel_direction`, `show_holes`, and `include_reachable_streets` in [`create_drive_time_areas()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#create-drive-time-areas)
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/)
# * Fixes [export_image](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/?highlight=export_image#arcgis.raster.ImageryLayer.export_image) failure on images with a [raster function template](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.RFT/) containing a [constant function](http://desktop.arcgis.com/en/arcmap/10.3/manage-data/raster-and-images/constant-function.htm) that requires input `RasterInfo` applied
# * Fixes issue when `service_url` parameter used to [`ImageLayer.rasters.add()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterManager.add) rasters to ImageryLayer
# * Fixes issue with [`get_samples()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.get_samples) failing with large payloads
# * Fixes to how [`convert_raster_to_feature()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#convert-raster-to-feature) reads input properties
# * Fixes to how [`train_classifier()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#train-classifier) parses input layer
# #### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/)
# * Fixes issue with [`classify`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#classify) and [`segment`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#arcgis.raster.analytics.segment) not honoring extent
# * Fixes error with [`optimum_travel_cost_network()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#optimum-travel-cost-network) when using `output_neighbor_network_name` parameter
# #### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/)
# * Fixes issue where raster functions errored out when displaying results of [`raster functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/) with private image services from different Web GIS portals
# * Fixes issue in [`raster functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#) where jobs did not honor `rendering_rule` setting
# * Fixes [`curvature`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#arcgis.raster.functions.curvature) function outputs
# * Fixes [`gvitm`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#gvitm) documentation. (See `Green Vegetation Index` at [`raster function objects`](https://developers.arcgis.com/documentation/common-data-types/raster-function-objects.htm) for reference)
# #### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/#module-arcgis.geoanalytics)
# * Fixes issue  with [`geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/#module-arcgis.geoanalytics) tools failing to write output to `Big Data File Shares`
# #### [`arcgis.geoprocessing`](https://developers.arcgis.com/python/api-reference/arcgis.geoprocessing/)
# * Improves [`geoprocessing.import_toolbox()`](https://developers.arcgis.com/python/api-reference/arcgis.geoprocessing/#arcgis.geoprocessing.import_toolbox) load time
# * Fixes [`geoprocessing`](https://developers.arcgis.com/python/api-reference/arcgis.geoprocessing/#) functions to accept `item` of type `Image Collection`
# #### [`arcgis.mapping`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/)
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#)
# * Fixes issue with [`map widget.save()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.save) not saving layer input as a `dictionary` with [`map widget.add_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.add_layer)
# * Fixes [`map`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) to add `Raster` from a datastore and display output from a raster rendering service
# * Fixes issue with [`map widget`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) not displaying in JupyterLab
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)
# * Fixes issue when [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) would now work with output from LabelImg tool
# * Fixes [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector) to work with all combinations of grid sizes
# * Improves performance for [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/) by making use of all GPUs present on a device
# * Improves [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector) to create grid size, aspect ratios, and zoom by reading dataset
# * Fixes [`UnetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier) to accept 0 for background value
# * Fixes [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector) training error when resizing empty tensor in batch
# * Fixes known issue with [`object detection`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#detect-objects) padding
# * Fixes issue with [`show_results()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.UnetClassifier.show_results) improperly visualizing results with multispectral data using the `UnetClassifier`
