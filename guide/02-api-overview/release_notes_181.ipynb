# %% [markdown]
# # What's new in version 1.8.1

# %% [markdown]
# ## New

# %% [markdown]
# ### New [Guides](https://developers.arcgis.com/python/guide/)
#  * [Labeling text using Doccano](https://developers.arcgis.com/python/guide/labeling-text-using-doccano)
#  * [Point Cloud Segmentation using PointCNN](https://developers.arcgis.com/python/guide/point-cloud-segmentation-using-pointcnn)
#  * [Working with Multispectral Data](https://developers.arcgis.com/python/guide/working-with-multispectral-data)

# %% [markdown]
# ### New [Samples](https://developers.arcgis.com/python/sample-notebooks/)
#  * [Shipwrecks detection using bathymetric data](https://developers.arcgis.com/python/sample-notebooks/shipwrecks-detection-using-bathymetric-data/)
#  * [Visualize monthly changes in Hirakund reservoir using video](https://developers.arcgis.com/python/sample-notebooks/visualize-monthly-changes-in-hirakund-reservoir-using-video)
#  * [Data Visualization: Construction permits, part 1/2](https://developers.arcgis.com/python/sample-notebooks/analyze-patterns-in-construction-permits-part1)
#  * [Data Summarization: Construction permits, part 2/2](https://developers.arcgis.com/python/sample-notebooks/analyze-patterns-in-construction-permits-part2)
#  * [Analyzing United States tornadoes](https://developers.arcgis.com/python/sample-notebooks/analyze-us-tornadoes)
#  * [Which college district has the fewest low-income families?](https://developers.arcgis.com/python/sample-notebooks/which-college-district-has-the-fewest-low-income-families)
#  * [Data Preparation: Hurricane analysis, part 1/3](https://developers.arcgis.com/python/sample-notebooks/part1-prepare-hurricane-data)
#  * [Exploratory Statistics: Hurricane analysis, part 2/3](https://developers.arcgis.com/python/sample-notebooks/part2-explore-hurricane-tracks)
#  * [Correlation: Hurricane analysis, part 3/3](https://developers.arcgis.com/python/sample-notebooks/part3-analyze-hurricane-tracks)
#  * [Raster Analytics: Calculate wildfire landslide risk](https://developers.arcgis.com/python/sample-notebooks/calculate-post-fire-landslide-risk)

# %% [markdown]
#     * `hosted feature services`, `web maps`, `web mapping applications` or any other `text-based` items
# * Enables [`UserManager.create()`]() to use [New Member Defaults](https://doc.arcgis.com/en/arcgis-online/administer/configure-new-member-defaults.htm) when set if corresponding arguments not provided
# * Adds ability to specify an `item_id` value for:
# * Enhancements to field name mapping in [`clone_items()`]() for `Web Applications`, `Dashboards`, and `Surveys`
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/)
# * Adds [`arcgis.gis.tasks`](https://developers.arcgis.com/python/api-reference/arcgis.gis.tasks/) submodule to work with scheduling `Notebook Items`:
#  * [`TaskManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.tasks/#taskmanager)
#  * [`Task`](https://developers.arcgis.com/python/api-reference/arcgis.gis.tasks/#task)
#  * [`Run`](https://developers.arcgis.com/python/api-reference/arcgis.gis.tasks/#run)
# * Adds [`GroupMigrationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#groupmigrationmanager) class
#  * Supports content migration betweeen `Enterprise 10.8.1` portals [`Group`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#group) to [`Group`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#group), **preserving itemId values**:
#  * Adds [`migration`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Group.migration) property to [`Group`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#group) to access [`GroupMigrationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#groupmigrationmanager)
#  * [`ContentManager.add()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.add)
#  * [`ContentManager.create_service()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.create_service)
#  * [`ContentManager.import_data()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.import_data)
#  * [`Item.publish()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.publish)
# * Adds support for adding [`WMTS Services`](https://enterprise.arcgis.com/en/server/latest/publish-services/windows/wmts-services.htm) as [`items`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item) - ([OGC WMTS Specification](https://www.ogc.org/standards/wmts))
# * Adds [`PortalDataStore`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#portaldatastore) class

# %% [markdown]
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#)
# * Adds `NotebookServer`, `MissionServer`, and `WorkflowManager` as `function` value options to [`Federation.update()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#federation) method
# * Adds [`AGOLUsageReports`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#agolusagereports) documentation to [API Reference](https://developers.arcgis.com/python/api-reference/index/)

# %% [markdown]
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/)
# * Adds [`ItemInformationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#iteminformationmanager) documentation to [API Reference](https://developers.arcgis.com/python/api-reference/index/)
# * Adds code sample to connect to stand-alone server (See [Usage Example #2](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#server))

# %% [markdown]
# #### [`arcgis.gis.nb`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#)
# * Adds `recent_statistics` property to the object returned from the [`NotebookServer.system`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#notebookserver) property
# * Adds support for expiration value configured from the [`NotebookServer`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#notebookserver)

# %% [markdown]
# * Adds support for `as_df` parameter on [`query()`]() operation against layers that do not suppport pagination#### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#)
# * Adds `transformations` parameter to [`SyncManager.create()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.SyncManager.create) to support 2-Way replication
# * Adds attributes to [`Spatially Enabled Dataframe`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor)
#  * [`sanitize_column_names()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.sanitize_column_names) method to ensure columns names are valid for [`to_featurelayer()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featurelayer) and/or [`to_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featureclass) methods
#  * [`renderer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.renderer) property to access dataframe renderer
# * Adds `geometry_column` parameter to [`pd.Dataframe.spatial.from_df()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_df) method

# %% [markdown]
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/)
# * Adds [`RasterCollection`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#rastercollection) class
# * Adds [`ImageryLayerCacheManager`]() documentation to [API Reference](https://developers.arcgis.com/python/api-reference/index/)
# * Adds properties to [`Raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#raster) class:
#  * [`vmin`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.Raster.vmin)
#  * [`vmax`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.Raster.vmax)
# * Adds [`slices()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.slices) method to [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer) class
# * Adds `slice_id` parameter to the [`ImageryLayer.export_image()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.export_image) method

# %% [markdown]
# * Adds functions:
#  * cycle_length
#  * cycle_unit
#  * rmse
#  * r2
#  * slope_p_value
#  * `percentile_value` and `process_as_multidimensional` parameters
#  * `PERCENTILE` option for `statistic_type` parameter
#  * New `reference_mean_raster` parameter
#  * EXTERNAL_RASTER as option for `calculation_interval` parameter
# * Deprecates functions -
#  * Sofware raises warning message when older tool is used and directions on which tool to use as replacement:
# #### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/)
#  * [`optimal_path_as_line`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#optimal-path-as-line)
#  * [`optimal_region_connetions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#opritmal-region-connections)
#  * [`analyze_changes_using_ccdc`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#analyze-changes-using-ccds)
#  * [`detect_change_using_change_analysis_raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#detect-change-using-change-analysis-raster)
#  * [`manage_multidimensional_raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#manage-multidimensional-raster)
#  * [`sample`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#sample)
# * Adds new parameters to [`generate_trend_raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#generate-trend-raster)
# * Adds functionality to [`summarize_raster_within`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#summarize-raster-within)
# * Adds functionality to [`generate_multidimensional_anomaly`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#generate-multidimensional-anomaly)
#    * [`optimum_travel_cost_network`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#optimum-travel-cost-network)
#    * [`determine_travel_costpath_as_polyline`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#determine-travel-costpath-as-polyline)
#    * [`costpath_as_polyline`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#costpath-as-polyline)

# %% [markdown]
# * Adds new functions:
# * Adds `sentinel` functions:
# * Adds parameters to [`shaded_relief()`](https://doc.arcgis.com/en/arcgis-online/administer/configure-new-member-defaults.htm)
#   * `colorramp`
#   * `hillshade_type`#### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/)
#  * [`generate_trend`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#generate-trend)
#  * [`predict_using_trend`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#predict-using-trend)
#  * [`linear_spectral_unmixing`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#linear-spectral-unmixing)
#  * [`multidimensional_filter`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#multidimensional-filter)
#  * [`s1_radiometric_calibration`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#st1-radiometric-calibration)
#  * [`s1_thermal_noise_removals`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#s1-thermal-noise-removal)
#  * [`interpolate_irregular_data`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#interpolate-irregular-data)

# %% [markdown]
#  * `output_back_direction_raster`
#  * `output_source_direction_raster_name`
#  * `output_source_location_raster_name`
#  * `output_distance-accumulation_raster_name`
#  * `generate_back_direction_band`
#  * `generate_source_row_column_bands`
# * Deprecates functions:
#  * Sofware raises warning message when older tool is used and directions on which tool to use as replacement:
#     * Calculate Distance
#     * Calculate Travel Cost
#     * Cost Allocation
#     * Cost Back Link
#     * Cost Distance
#     * Cost Path
#     * Euclidean Allocation
#     * Euclidean Back Direction
#     * Euclidian Direction
#     * Euclidean Distance
#     * Path Distance
#     * Path Distance Allocation
#     * Path Distance Back Link
# #### [`arcgis.raster.functions.gbl`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#)
# * Adds parameters to [`distance_accumulation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-accumulation)
# * Adds `percentile_value` parameter to [`zonal_statisitics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#zonal-statistics)
# * Adds `PERCENTILE` `statistic_type` to [`zonal_statisitics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#zonal-statistics)
# * Removes parameter from [`distance_accumulation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-accumulation)
# * Enhances [`distance_accumulation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-accumulation) to generate multiple outputs
# * Enhances [`distance_allocation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-allocation) to generate multiple outputs
# * Removes parameter from [`distance_allocation`]([`distance_accumulation`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#distance-allocation)
# * Adds [`optimal_path_as_raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#optimal-path-as-raster) function

# %% [markdown]
# * Enables tools to run in asynchronous manner (See `future` parameter on tools)#### [`arcgis.raster.orthomapping`](https://developers.arcgis.com/python/api-reference/arcgis.raster.orthomapping/#)

# %% [markdown]
#    * `time_boundary_split`
#    * `time_split_unit`
#    * `time_reference`#### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/)
# * Adds new function to [`analyze_patterns`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/)
#  * [`gwr`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#gwr)
# * Adds documentation in [`find_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/):
#  * parameters to [`find_dwell_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#find-dwell-locations)

# %% [markdown]
#  * `match_out_of_range`
#  * `location_type`
#  * `lang_code`
#  * `source_country`
#  * `feature_types`
#  * `location_type`
#  * `lang_code`
#  * `search_extent`
#  * `max_suggestions`
#  * `country_code`#### [`arcgis.geocoding`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#)
# * Adds missing parameter documentation for [`geocode()`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#geocode) function
# * Adds missing parameter decumentation for [`reverse_geocode()`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#reverse-geocode) function
# * Adds missing parameter documentation for [`suggest()`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#suggest)

# %% [markdown]
# to support `OGC Layers`:
# #### [`arcgis.mapping`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#webmap)
# * New [`arcgis.mapping.ogc`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#) submodule
#   * [`CSVLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#csvlayer)
#   * [`GeoJSONLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#geojsonlayer)
#   * [`GeoRSSLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#georsslayer)
#   * [`WMSLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#wmslayer)
#   * [`WMTSLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#wmtslayer)
# * Adds ability to set the [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#webmap) `basemap` to instances of:
#   * [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#webmap)
#   * [`MapImageLayer`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#mapimagelayer)
#   * [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer)
#   * [`MapView`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview)
# > NOTE:  See [`WebMap.basemap` Usage Example /#3](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.basemap)

# %% [markdown]
# * Updates the [`map widget`]() to use [`JavaScript API 4.15`](https://developers.arcgis.com/javascript/latest/api-reference/)
# * Adds properties to [`map widget`]():
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/)
# * Adds support for snychronized navigation between mutiple [`MapViews`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview)
#   * [`sync_navigation(_mapview_)`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.sync_navigation) - See [`USAGE EXAMPLE`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.sync_navigation)
#   * [`unsync_navigation(_mapview_)`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.unsync_navigation) - unlinks navitation between two `MapView` instances
#  * [`scale`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.scale)
#  * [`snap_to_zoom`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.snap_to_zoom)

# %% [markdown]
#
#     * Allows administrators to use custom parameters when enabling location tracking
#     * Sets description and snippet of the created item#### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps/)
#  * ##### [workforce](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/)
#     * New [`web_app_link`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/#arcgis.apps.workforce.Assignment.web_app_link) property on Workforce [`Assignment`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/#assignment) class
#     * Sets [`assigned_date`]() argument value if none is entered when [`Assignment`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce/#assignment) created
#  * ##### [tracker](https://developers.arcgis.com/python/api-reference/arcgis.apps.tracker/)

# %% [markdown]
# * Adds models to module:
# * Adds [`TensorFlow`](https://www.tensorflow.org/) backend support to the following models, enabling [`tf-lite`](https://www.tensorflow.org/lite/models) model creation for deployment to mobile devices and integration with `AppStudio` and `Survey123` (private beta support):
#  * per class precision recall and f1score
#  * balanced loss
#  * focal loss
#  * mixup aug
# * Adds Multiple-GPU support to:
# * Adds Model Extension support
#  * documents `max_sampling_points` parameter for raster rendering
# * Adds `NoData` support to image segmentation models:
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)
#  * [`FullyConnectedNetwork`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#fullyconnectednetwork) - fully connected neural network for tabular/feature data
#  * [`MLModel`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#mlmodel) - integrates Scikit-learn's machine learning models
#  * [`SuperResolution`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#superesolution)
#  * [`YOLOv3`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#yolov3)
#  * [`FasterRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#fasterrcnn)
# * Adds [`ModelExtension`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#modelextension) class - for customized sources
# * Adds [`prepare_tabulardata()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-tabulardata) function for data preperation
# * Adds [`Transform3d`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#transform3d) class for data augmentation to `PointCloud` data
#  * [`Unet`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier)
#  * [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier)
#  * [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector)
# * Adds [`load_model()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#load-model) function for direct loading of any model
# * Adds visualization, data augmentation, and [3d transformation](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#transform3d) support to [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn) model
# * Enhances [`UnetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier) and [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier) models by adding:
#  * [`MaskRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#maskrcnn)
#  * [`Unet`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier)
#  * [`DeepLab`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#deeplab)
#  * [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier)
# * Adds [`PointCNN.show_results()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.show_results) documentation to [API Reference](https://developers.arcgis.com/python/api-reference/index/)
# * Adds [`predict_h5()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.predict_h5) method to [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn) model
# * Adds support for non continous class mappings when using [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.prepare_data) for [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn)
# * Adds `iters_per_epoch` parameter documentation to [`PointCNN.fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.fit)
# * Enhances [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) with `Keyword Arguments` table to document parameters pertinent to multispectral imagery input
# * Adds performance metric functions to [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#entityrecognizer)
#  * [`metrics_per_label()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.metrics_per_label)
#  * [`precision_score()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.precision_score)
#  * [`recall_score()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.recall_score)
#  * [`f1_score()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.EntityRecognizer.f1_score)
#  * [`Unet`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unetclassifier)
#  * [`DeepLab`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#deeplab)
#  * [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier)
# * Enhances visualizations when using [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn) workflows

# %% [markdown]
# ## Fixes

# %% [markdown]
# ### [Guides](https://developers.arcgis.com/python/guide/)
# * Updates to [Working with different authentication schemes](https://developers.arcgis.com/python/guide/working-with-different-authentication-schemes/)
#  * clarifies non-interactive login experience
#  * clarifies installation steps
#  * clarifies prerequisites* Updates to [Geospatial deep learning with [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)](https://developers.arcgis.com/python/guide/geospatial-deep-learning/)
# * Updates to [Named Entity Extraction Workflow with [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)](https://developers.arcgis.com/python/guide/how-named-entity-recognition-works/)

# %% [markdown]
# ### [Samples](https://developers.arcgis.com/python/sample-notebooks/)
# * Updates to [Finding suitable spots for placing heart defibrillator equipments in public](https://developers.arcgis.com/python/sample-notebooks/finding-suitable-spots-for-aed-devices-using-raster-analytics/)
#  * formatting changes
# * Updates to [Safe streets to schools](https://developers.arcgis.com/python/sample-notebooks/safe-streets-to-schools/)
#  * zoom levels adjusted for `maps`
# * Updates to [
# Land Cover Classification using Satellite Imagery and Deep Learning](https://developers.arcgis.com/python/sample-notebooks/land-cover-classification-using-unet/)
#  * refines `search` for data
# * Updates to [Detecting Swimming Pools using Satellite Imagery and Deep Learning](https://developers.arcgis.com/python/sample-notebooks/detecting-swimming-pools-using-satellite-image-and-deep-learning/)
#  * adjusts library imports
# * Updates to [Madison city crime analysis](https://developers.arcgis.com/python/sample-notebooks/information-extraction-from-madison-city-crime-incident-reports-using-deep-learning/)
#  * clarifies prerequisites * use of [`filter`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Layer.filter) property to query [`FeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayer)

# %% [markdown]
# * Removes incorrect Exception messge on [`User.update_license_type()`]() and [`User.update_role()`] when `.`, `@` and/or `-` in `username`
# * Fixes 301/redirect error with PKI authentication schemes not using the web adaptor
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis)
# * Removes incorrect Exception message on [`UserManager.create()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.UserManager.create) when `.`, `@` and/or `-` in `username` argument
# * Fixes error when invalid input passed to `get()` method on [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#contentmanager), [`UserManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#usermanager), or [`GroupManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#groupmanager)
# * Fixes [`Item.copy()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.copy) method failing to copy the `url` property to the new `item`
# * Fixes input format when using [`assign_to_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.CategorySchemaManager.assign_to_items) for [`Group`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#group) categories

# %% [markdown]
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/)
# * Fixes issue where updating the Web GIS [`name`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#arcgis.gis.admin.UX.name) did not update Home Page

# %% [markdown]
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/)
# * Fixes [`to_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featureclass) method on the [`Spatially Enabled Dataframe`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor) dropping `Z` values from geometries
# * Fixes [`from_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_featureclass) method on the [`Spatially Enabled Dataframe`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor) nullifying zero-length polyline geometries
# * Fixes issue with geometry operations on [`Spatially Enabled Dataframe.SHAPE`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor) column not preserving spatial reference
# * Improves performance of [`Spatially Enabled Dataframe`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor) [`from_xy()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_xy) method
# * Updates standard [`feature analysis functions`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/#) reference documentation to refer to [`Feature Input`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/#arcgis-features-analysis-module)
# * Fixes error with [`true_centroid()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/?highlight=true_centroid#arcgis.features.GeoAccessor.true_centroid) on the `Spatially Enabled DataFrame` in `ArcPy` environments

# %% [markdown]
#   * `bin_type`
#   * `bin_size`
#   * `bin_size_unit`
#   * `future`#### [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/)
# * [`summarize_data`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/)
#  * Adds parameters to [`aggregate_points()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#aggregate-points)

# %% [markdown]
# #### [`arcgis.raster.functions.gbl`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#)
# * Enhances [`region_group`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#region-group) parameter documentation

# %% [markdown]
# #### [`arcgis.geometry`](https://developers.arcgis.com/python/api-reference/arcgis.geometry/)
# * Enhancements to `is_valid` property on `Geometry` instances. (See [`Example`](https://developers.arcgis.com/python/api-reference/arcgis.geometry/).)
# * Fixes code to compare whether two [`SpatialReferences`](https://developers.arcgis.com/python/api-reference/arcgis.geometry/#spatialreference) are equal

# %% [markdown]
# #### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/)
# * Fixes issue with [`classify()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#classify) when second raster not specified

# %% [markdown]
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/)
# * Fixes issue with [`zoom_to_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#arcgis.widgets.MapView.zoom_to_layer) not working with spatial reference in `wkt` formatt

# %% [markdown]
#
#    * Fixes support service name conflicts#### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps/)
#  * ##### [tracker](https://developers.arcgis.com/python/api-reference/arcgis.apps.tracker/)

# %% [markdown]
# * Improves overall Exception handling
# * Increases flexibility of `from_model()` methods in ArcGIS Models to allow for different backends
# * Fixes `show_batch()` error with multispectral models
# * Fixes error with `show_results()` when using multispectral data
#  * preserves point cloud formatting and version of input and output
#  * fixes output and messaging when `print_metrics` is `True`
#  * fixes loss of information in the `las` file
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#)
# * Fixes metric calculation error in [`PointCNN.compute_precision_recall()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.compute_precision_recall())
# * Fixes error when using [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) for [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier) when balancing statistics are not present
# * Fixes error with [`PSPNetClassifer.lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PSPNetClassifier.lr_find) with all `backbones`
# * Fixes display issues with `lr.find()` in [`DeepLab`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#deeplab) and [`PSPNetClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pspnetclassifier)
# * Fixes [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) errors when the training data was created with `Output No Feature Data` option checked
# * Fixes error with [`export_point_dataset()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#export-point-dataset) on [`PointCNN`]() when working with data that has non-contiguous classes
# * Fixes [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn.lr_find) and [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn.fit) functions when used with [`export_point_dataset()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#export-point-dataset) output created when `max_points` argument exceeds default
# * Fixes errors with [`RetinaNet.predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.RetinaNet.predict) on objects created with `resnet101` or `resnet152` backbones
# * Multiple improvements to the [`predict_las()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.predict_las) function using the `PointCNN` model
# * Removal of 'non-zero' classcodes specific accuracy at completion of epoch when using [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn)
# * Change default behavior of [`export_point_dataset( )`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#export-point-dataset) `extra_features` to empty
