# %% [markdown]
# # What's new in version 1.9.0
# * Adds support for [**ArcGIS Enterprise on Kubernetes**](https://www.esri.com/arcgis-blog/products/arcgis-enterprise/announcements/what-is-arcgis-enterprise-on-kubernetes/)
# * Adds classes to manage [`ArcGIS Velocity`](https://doc.arcgis.com/en/iot/get-started/what-is-arcgis-velocity.htm) functionality
# * Enhances [API Reference for the ArcGIS API for Python](https://developers.arcgis.com/python/api-reference/)
#   * Adds text emphasis, links to class documentation when objects are returned, and code snippets:
#
# ## New
#
# ### [`Guides`](https://developers.arcgis.com/python/guide/)
#
# * [Imagery and raster analysis](https://developers.arcgis.com/python/guide/)
#   * New Guides:
#     * [Create Imagery Layers](https://developers.arcgis.com/python/guide/creating-imagery-layers)
# * [Deep Learning with ArcGIS](https://developers.arcgis.com/python/guide/)
#   * Updates guides for default unfrozen backbone in text models
#   * New Guides:
#     * [Track objects using SiamMask](https://developers.arcgis.com/python/guide/track-objects-using-siammask)
#     * [Multi-object Tracking using ObjectTracker](https://developers.arcgis.com/python/guide/multi-object-tracking-using-object-tracker)
#     * Adds _Choosing a different backbone than the default_ section and various text edits
# * [Geocoding guides](https://developers.arcgis.com/python/guide)
#   * [Part 1 - What is geocoding?](https://developers.arcgis.com/python/guide/part1-what-is-geocoding)
#   * [Part 2 - Locating addresses](https://developers.arcgis.com/python/guide/part2-locating-addresses)
#   * [Part 3 - Finding points of interest](https://developers.arcgis.com/python/guide/part3-finding-point-of-interests)
#   * [Part 4 - Batch geocode](https://developers.arcgis.com/python/guide/part4-batch-geocoding)
#   * [Part 5 - Reverse geocode](https://developers.arcgis.com/python/guide/part5-reverse-geocoding)
#   * [Part 6 - Custom geocoders](https://developers.arcgis.com/python/guide/part6-working-with-custom-geocoders)
#   * [Part 7 - Utility functions for geocoding](https://developers.arcgis.com/python/guide/part7-utility-functions-for-geocoding)
#
# ### [`Samples`](https://developers.arcgis.com/python/sample-notebooks/)
#
# * Updates Runtime used in `Try It Live` Notebooks to 5.0
# * [GIS analysts and data scientists](https://developers.arcgis.com/python/sample-notebooks)
#   * Updates samples for default unfrozen backbone in text models
#   * New Samples:
#     * [Determining site suitability for oil palm plantation](https://developers.arcgis.com/python/sample-notebooks/determining-site-suitability-for-oil-palm-plantation)
#     * [Model explainibility for ML Models](https://developers.arcgis.com/python/sample-notebooks/model-explainability-using-shap-for-tabular-data/)
#     * [Supervised learning of tabular data using AutoML](https://developers.arcgis.com/python/sample-notebooks/tabular-data-supervised-learning-using-automl)
#   * Updates symbols used in [Identifying suitable sites for new ALS clinics using location allocation analysis](https://developers.arcgis.com/python/sample-notebooks/identifying-suitable-sites-for-als-clinics-using-location-allocation-analysis/)
#   * Updates [SAR to RGB image translation using CycleGAN](https://developers.arcgis.com/python/sample-notebooks/sar-to-rgb-image-translation-using-cyclegan/) to include additional explanation and minor modifications to functions
# * [Content publishers](https://developers.arcgis.com/python/sample-notebooks)
#   * Updates to [Publishing web maps and web scenes](https://developers.arcgis.com/python/sample-notebooks/publishing-web-maps-and-web-scenes/)
#
# ### Module Changes
#
#   * Adds Usage Examples for connecting with `token` and `api_key` parameters
#   * Adds note on certificate path to `verify_cert` parameter
#   * Adds properties:
#     * `servers`
#     * `languages`
#     * `regions`
#   * Adds ability to publish OGC Feature Service from existing Feature Layer `item` using the `output_type` parameter
#   * Adds `can_delete` property to check for ability to remove item
# * [`User`]()
#
#
# * Adds documentation for:
#
# * Adds documentation for:
#
# * Adds classes to module:
#
#
# * Adds internal job status checks for asynchronous jobs that impact many methods in the module
#   * Adds capability to run following methods asynchronously:
#
#     * `overwrite`
#     * `description`
#     * `tags`
#     * `snippet`
#     * `set_item_id`
#   * Adds ability to run following functions asynchronously:
#   * Adds ability to run following functions asynchronously:
#     * `return_metadata`
#     * `return_url`
#     * `max_records`
#     * `offset`
#
# * Adds numerous code snippets, documentation improvements and corrections to module and all submodules
# * Adds support for publishing a single image
# * Adds support for [_SpatioTemporal Asset Catalogs_](https://stacspec.org/)
#   * Updates `nodata` values to appear white with tiles only services
#
# * Adds full support for creating Dynamic Imagery Layers to ArcGIS Online with `tiles_only=False` argument with those functions accepting it
#   * Corrects example for `interval_ranges` parameter
#   * New parameters:
#     * `dimensionless`
#     * `percentile_value`
#     * `percentile_interpolation_type`
#   * Adds `PERCENTILE` as option for `aggregation_method` argument
#   * Updates `context` parameter documentation with  `upload_properties` key for parallel processing and progress bar
#   * Adds `Tiled Imagery Layer` as an option for the `raster_type_name` argument
#   * Adds numerous Usage Examples to the reference documentation
#   * Removes `tiles_only` parameter
#
#   * `PERCENTILE` as option for `aggregate_function` argument
#   * New parameters:
#     * `dimensionless`
#     * `percentile_value`
#     * `percentile_interpolation_type`
#   * `ignore_nodata` parameter
#
# * Adds function:
#
#   * Adds documentation and code snippet
#   * Adds parameters:
#     * `auto_renew`
#     * `upload_properties` - to support parallel processing and provide option for progress bar
#
# * Updates how methods handle setting default `travel_mode` when not supplied
#
# * Adds `WKT` support for `context` parameter in all functions
#
#     * `arcade_split`
#     * `split_boundary`
#     * Updates `include_overlaps` parameter documentation
#     * Adds code sample for the `field_mappings` parameter
#
# * Adds submodule documentation:
# * Adds new classes:
#   * Adds reference documentation for:
#
#
# * Adds new classes:
#
# * Enhances training (`fit()` method) for all models to add the `average precision score` as an option for the `monitor` parameter
# * Enhances `available_metrics` property to report in `ArcGIS Pro`
# * Adds support for loading pre-trained Imagery models in an offline mode
# * Adds `Experimental` support for `tflite` as the framework for:
#
#   * Adds support for custom `DataBunch`
#   * **New Models**
#   * Adds note to `predict()` and `predict_video()` methods that support is only for RGB images
#   * **New Models**
#   * Adds [SHAP Interpretability](https://towardsdatascience.com/shap-a-reliable-way-to-analyze-your-model-interpretability-874294d30af6) to `predict()` with new `explain` and `explain_index` parameters
#   * **New Class**
#   * **New Models**
#     * Adds `rows` and `max_len` parameters to the `show_batch()` utility function
#     * Adds `freeze()` method to transformer based models
#       * adds support for custom labels
#       * removes using `FastTokenizers` from transformer backbones
#       * adds `pretrained_path` and `working_dir` parameters as keyword argument options
#   * Adds support for loading models that were saved with `save_inference_file` argument set to False
#
#
# ## Fixes
#
# ### [`Guides`](https://developers.arcgis.com/python/guide/)
#
# * [Get Started](https://developers.arcgis.com/python/guide/)
#   * [Install and set up](https://developers.arcgis.com/python/guide/install-and-set-up/)
#     * Updates to Table of Contents
#     * Updates links to Deep Learning installer and instructions
#     * Adds link to [Deep Learning Essentials](https://anaconda.org/esri/deep-learning-essentials) as alternative for installing Deep Learning Frameworks
# * [Deep Learning with ArcGIS](https://developers.arcgis.com/python/guide/)
# * [Working with the Spatially Enabled DataFrame](https://developers.arcgis.com/python/guide/)
#   * Spelling and grammar edits to [Introduction to the Spatially Enabled DataFrame ](https://developers.arcgis.com/python/guide/introduction-to-the-spatially-enabled-dataframe/)
#
# ### [`Samples`](https://developers.arcgis.com/python/sample-notebooks/)
#
# * [GIS analysts and data scientists](https://developers.arcgis.com/python/sample-notebooks)
#   * Batch size reduced in ChangeDetector samples to avoid `cuda` errors
#   * Connection edits in [Land Parcel Extraction using Edge Detection model](https://developers.arcgis.com/python/sample-notebooks/land-parcel-extraction-using-edge-detection-deep-learning-model/)
#   * Fixes `ValueError` errors in [Time Series Analysis of the 2019 Novel Coronavirus Pandemic](https://developers.arcgis.com/python/sample-notebooks/covid19-part2-timeseries-analysis/)
#
# ### Module Changes
#
#   * Fixes response handling when `GIS` object initialized with either the `api_key` or `client_id` parameter
#   * Fixes error with `tables` property on items sourced from cached Map Services
#
#
#   * Fixes run failures with `measurement_type=StraightLine` on:
#
#   * Fixes `Unable to complete operation` error when `from_geometry` argument is a dictionary
#   * Removes internal properties from documentation
#   * Fixes failurs with applying or calling operations on `ArcPy` engine Raster objects with raster functions applied
#   * Fixes issue initializing an object in environments with `ArcPy`if all the input rasters point to the same Raster object
#   * Fixes issue initializing an object from local `mosaic datasets` where output object is missing `Raster` key
#     * default value _FIRST_ not set if not value is provided
#     * output is not for object created from image services
#
# * Fixes failures caused by missing response information in job results when analyzing `ArcGIS Online` content
#   * Fixes issues when data to upload exceeds 2GB
#   * Fixes `GIS('pro')` or `GIS('home')` authentication while logged into ArcGIS Online and creating hosted imagery from local raster datasets
#   * Fixes `GIS('pro')` or `GIS('home')` authentication while logged into ArcGIS Online and creating hosted imagery from local raster datasets
#   * Fixes `NameError` when using the `input_multidimensional_rasters` parameter
#
# * [`manage_data`]()
#
# * Fixes issue with `properties` returned from ArcGIS Enterprise configuration when accessed from [Notebook Server](https://enterprise.arcgis.com/en/notebook/)
#
# * Fixes `FileExistsErrors` when training models (`fit()`) with MultiGPU machines
#   * Fixes `AttributeError` with segmentation models' improper handling of fastai databunches
#   * Fixes edge detection models' inferencing output that does not display output raster without changing symbology to `Classify` if the training data has discontinuous classes
#     * Removes `UserWarning` when using `linknet` architecture to create model
#   * Fixes `predict()` failures when databunch is prepared with `resize_to` parameter
#   * Fixes training failures with the `resnet18` and `resnet34` backbones:
#     * Fixes issue when using [Detect Objects Using Deep Learning](https://pro.arcgis.com/en/pro-app/latest/tool-reference/image-analyst/detect-objects-using-deep-learning.htm) tool in ArcGIS Pro on model trained with ArcGIS API for Python
#     * Fixes `RuntimeError` when using save as tflite if data is kitti type in object detection
#     * Fixes errors when running `import arcgis` caused by internal import statements
#     * Fixes [`save()`]() method when object initialized without `data`
#  * Fixes incorrect output with `rows` parameter in `show_results()` when using the `hourglass` architecture:
#     * Fixes incorrect output issues when:
#     * Fixes documentation for:
# * Adds standardized `output_names` for all [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/) and [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/) analysis tools
# * Updates the [`map widget`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview) to use JavaScript 4.19
#     * [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/)
#     * [`arcgis.geometry`](https://developers.arcgis.com/python/api-reference/arcgis.geometry/)
#     * [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/)
#   * [Inference only Text Models in [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)](https://developers.arcgis.com/python/guide/inference-only-text-models-in-arcgis-learn/)
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#)
# * [`GIS`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis)
#   * Adds [`notebook_server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.GIS.notebook_server) property to return the [`NotebookServer`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#notebookserver) registered with the organization
#   * Adds Note to [`map()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.GIS.map) documentation that IE 11 is no longer supported
#   * Adds [`velocity`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.GIS.velocity) property to manage `ArcGIS Velocity` functionality
# * [`Item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#item)
#   * Enhances [`usage()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.usage) method to allow entering custom date ranges
#   * Adds [`snapshots`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.snapshots) property to return notebook item snapshots
# * [`InvitationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#invitationmanager)
#   * Adds [`manage_invitations`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis._impl._invitations.InvitationManager.manage_invitations) method to allow users to accept or deny invitations by `invitationId`
# * [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#contentmanager)
#   * Adds `preserve_item_id` parameter to [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.clone_items) to keep the same `item_id` when target organization is **ArcGIS Enterprise 10.9 or later**
#   * Adds `culture_format` parameter to [`update()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.User.update) method
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/)
#   * [`AGOLAdminManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#agoladminmanager)
#     * Adds [`scheduled_tasks()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin/#arcgis.gis.admin.AGOLAdminManager.scheduled_tasks) method to allow `org_admins` to view scheduled [`tasks`](https://developers.arcgis.com/python/api-reference/arcgis.gis.tasks/#task)
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/)
#   * [`JobManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#jobmanager)
#   * [`Job`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server/#job)
# #### [`arcgis.gis.mission`](https://developers.arcgis.com/python/api-reference/arcgis.gis.mission/#)
#   * [`Mission`](https://developers.arcgis.com/python/api-reference/arcgis.gis.mission/#mission)
#   * [`MissionCatalog`](https://developers.arcgis.com/python/api-reference/arcgis.gis.mission/#missioncatalog)
#   * [`MissionJob`](https://developers.arcgis.com/python/api-reference/arcgis.gis.mission/#missionjob)
# #### [`arcgis.gis.nb`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#)
#   * [`SnapshotManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#snapshotmanager) class to manage [Notebook Snapshots](https://enterprise.arcgis.com/en/notebook/latest/use/windows/notebook-snapshots.htm#:~:text=Introduced%20at%20ArcGIS%20Enterprise%2010.9,files%20on%20the%20notebook%20item.)
#   * [`SnapShot`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#snapshot) class to represent individual notebook item snapshot
#   * [`SystemManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#systemmanager)
#   * [`DirectoryManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#directorymanager)
#   * [`Container`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#container)
#   * [`ContainerNotebook`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#containernotebook)
#   * [`WebAdaptor`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#webadaptor)
#   * [`WebAdaptorManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#webadaptormanager)
#   * [`LogManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#logmanager)
#   * [`SiteManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#sitemanager)
#   * [`MachineManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#machinemanager)
#   * [`Machine`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#machine)
#   * [`SecurityManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.nb/#securitymanager)
# #### [`arcgis.env`](https://developers.arcgis.com/python/api-reference/arcgis.env/)
# * Adds `WKT` support to [`process_spatial_reference`](https://developers.arcgis.com/python/api-reference/arcgis.env/#process-spatial-reference) and [`out_spatial_reference`](https://developers.arcgis.com/python/api-reference/arcgis.env/#out-spatial-reference)
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#)
# * [`FeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayer)
#   * Adds incremental checking of job status to [`append()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.append) when run asynchronously
#   * Adds _required_ to the `source_table_name` parameter in the API Reference documentation for [`append()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.append)
#     * [`append()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.append)
#   * Updates how [`edit_features()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.edit_features) sends request with large amounts of data
#   * Adds support for a list of [`feature`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#feature) objects as `adds` argument to [`edit_features()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.edit_features)
# * [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor)
#   * Adds `ValueError` to [`from_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.from_featureclass) if `location` argument is not correct format
# #### [`arcgis.features.managers`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#)
# * [`FeatureLayerCollectionManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#featurelayercollectionmanager)
#   * Adds parameters to [`create_view()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.create_view)
#     * [`add_to_definition()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.add_to_definition)
#     * [`delete_from_definition()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.delete_from_definition)
#     * [`update_definition()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.update_definition)
#   * Improves error messaging with [`overwrite()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerCollectionManager.overwrite) if outstanding replicas exist
# * [`FeatureLayerManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#featurelayermanager)
#     * [`add_to_definition()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerManager.add_to_definition)
#     * [`delete_from_definition()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerManager.delete_from_definition)
#     * [`update_definition()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features.managers.FeatureLayerManager.update_definition)
# * [`ParcelFabricManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#parcelfabricmanager)
#   * Adds [`divide()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#arcgis.features._parcel.ParcelFabricManager.divide) method
# * [`AttachmentManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#attachmentmanager)
#   * Adds parameters to the [`search()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers/#attachmentmanager.search) method
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#)
#   * [Raster](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#raster)
#     * create Raster objects from stac items with [`from_stac_item()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.Raster.from_stac_item)
#   * [RasterCollection](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#rastercollection)
#     * create RasterCollection objects from stac api search queries with [`from_stac_api()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterCollection.from_stac_api)
#     * create RasterCollection objects from stac catalogs with [`from_stac_catalog()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterCollection.from_stac_catlog)
# * [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer)
#   * Adds [`plot_histograms()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.project) method
#   * Updates [`export_image()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.export_image) to include `numpy_array` as an option for the `f` argument
#   * Adds full support for creating Dynamic Imagery Layers with the [`save(tiles_only=False)`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.save) argument
# #### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/)
# * [`aggregate_multidimensional_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#aggregate-multidimensional-raster)
# * Adds following to [`create_image_collection()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#create-image-collection) and [`copy_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#copy-raster)
# * [`create_image_collection()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#create-image-collection)
# #### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#)
# * Adds to [`aggregate()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#aggregate):
# * Adds to [`max()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions/#max)
# #### [`arcgis.raster.functions.gbl`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/)
#   * [`viewshed()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/#viewshed)
# * Deprecates [`least_cost_path()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.gbl/?#arcgis.raster.functions.gbl.least_cost_path) function
# #### [`arcgis.raster.utils`](https://developers.arcgis.com/python/api-reference/arcgis.raster.utils/)
# * [`upload_imagery_to_agol_userstore()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.utils/#upload-imagery-to-agol-userstore)
# #### [`arcgis.network`](https://developers.arcgis.com/python/api-reference/arcgis.network.toc/#)
# #### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/)
# * [`summarize_data`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#)
#   * Adds `keep_target` parameter to [`join_features()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#join-features)
#   * Adds parameters to [`reconstruct_tracks()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#reconstruct-tracks)
# * [`manage_data`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#)
#   * [`overlay_data()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#overlay-data)
#   * [`append_data()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#append_data)
# #### [`arcgis.mapping.ogc`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#)
#   * [`arcgis.mapping.forms`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.forms/)
#   * [`OGCFeatureService`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#ogcfeatureservice) to represent an OGC Feature Server
#   * [`OGCCollection`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.ogc/#ogccollection) to represent an individual OGC dataset
# * [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#webmap)
#     * [`forms`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.forms) property
#     * [`print()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc/#arcgis.mapping.WebMap.print) method
# #### [`arcgis.realtime`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#)
#   * [`Velocity`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#velocity)
#   * [`FeedsManager`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#feedsmanager)
#   * [`RealTimeAnalyticsManager`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#realtimeanalyticsmanager)
#   * [`BigDataAnalyticsManager`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#bigdataanalyticsmanager)
#   * [`Feed`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#feed)
#   * [`RealTimeAnalytics`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#realtimeanalytics)
#   * [`BigDataAnalytics`](https://developers.arcgis.com/python/api-reference/arcgis.realtime/#bigdataanalytics)
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)
#   * [`FeatureClassifier`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier)
#   * [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#singleshotdetector)
#   * [`RetinaNet`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#retinanet)
# * [`Data Preparation Methods`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#data-preparation-methods)
#   * Adds capability to select specific raster bands in  [`prepare_tabulardata()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.prepare_tabulardata) by using the `explanatory_rasters` parameter
# * [`Object Classification Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-classification-models)
# * [`Object Detection Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-detection-models)
#     * [MMDetection](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#mmdetection)
# * [`Feature, Tabular, and TimeSeries Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#feature-tabular-and-timeseries-models)
#     * [`AutoML`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#automl)
#     * [FullyConnectedNetwork](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#fullyconnectednetwork)
#     * [MLModel](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#mlmodel)
#   * [`MLModel`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#mlmodel)
#     * Adds publishing [`predict(prediction_type="raster")`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.predict) output directly to organization rather than locally
# * Change [`Inferencing Methods (Image Server)`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#inferencing-methods-image-server) to [`Inferencing Methods`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#inferencing-methods)
#     * [`Embeddings`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#embeddings)
# * [`Pixel Classification Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pixel-classification-models)
#     * [MMSegmentation](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#mmsegmentation)
# * [`Unstructured Text Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#unstructured-text-models)
#   * [`arcgis.learn.text module`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis-learn-text-module)
#     * [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#entityrecognizer)
#       * adds `allow_plot` documentation for [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#arcgis.learn.text.EntityRecognizer.lr_find)
#       * adds `show_progress` parameter to [`extract_entities()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#arcgis.learn.text.EntityRecognizer.extract_entities) method
#     * [`Inferencing Only Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text/#inference-only-models)
# * [`Model Management`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/?highlight=train_model#model-management)
#   * Adds warning to [`train_model()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#train-model) that it is not supported for ArcGIS Online
#   * Updates [`train_model()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#train-model) to process asynchronously
# * [`Image Translation Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#image-translation-models)
#   * [`ImageCaptioner`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#imagecaptioner)
#     * Adds additional documentation to `framework` parameter of the [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.ImageCaptioner.save) method
#   * [`Pix2Pix`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pix2pix)
#     * Adds [`supported_datasets`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.Pix2Pix.supported_datasets) property
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/)
# * Adds capability to view Tiled Imagery Layers in ArcGIS Online with the [`map widget`](https://developers.arcgis.com/python/api-reference/arcgis.widgets/#mapview)
#   * [Inference only Text Models in [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)](https://developers.arcgis.com/python/guide/inference-only-text-models-in-arcgis-learn/)
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#)
# * [`GIS`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#gis)
# * [`Item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#item)
#   * Fixes [`share()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.share) method when item is part of a [Hub](https://doc.arcgis.com/en/hub/get-started/what-is-arcgis-hub-.htm) and item is in a [`Group`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#group) and members can edit the item
#   * Fixes BUG-000136169 [`share()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.share) method fails to share item to shared update group when run by non-owner admin
#   * Fixes [`download()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.download) failures for `csv` files output from ArcGIS Online usage reports
#   * Fixes [`usage()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.Item.usage) issues if input Feature Service is empty or contains only [`Tables`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#table)
# * [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#contentmanager)
#   * Fixes failures when trying to use [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.ContentManager.clone_items) on items with optimized layers
# * [`UserManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#usermanager)
#   * Fixes [`search()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc/#arcgis.gis.UserManager.search) method return values to populate the `provider` property
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#)
# * [`FeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#featurelayer)
#   * Fixes issue with [`query(as_df=True)`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.FeatureLayer.query) failing if `FeatureLayer` has null geometries
# * [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#geoaccessor)
#   * Fixes [`to_featureset()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#arcgis.features.GeoAccessor.to_featureset) failure if DataFrame contains a `DateTime` field with all `NaT` values
#   * Fixes issue with object created using the [`from_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#table) method on a layer with undefined Geometry column ([`Table`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc/#table)) was not passing an empty renderer
# #### [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/)
# * [`arcgis.features.use_proximity`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity/#)
#     * [`connect_origins_to_destinations()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/#connect-origins-to-destinations)
#     * [`find_nearest()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis/#find-nearest)
# * [`arcgis.features.summarize_data()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#)
#   * Fixes [`summarize_within()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data/#summarize-within) to make `sum_within_layer` optional so `bin_type`, `bin_size`, and `bin_size_unit` can be used
# #### [`arcgis.raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#)
# * [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer)
#   * Fixes [`identify()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.identify) to accept a dictionary as the `geometry` argument
#   * Fixes issue when [`colormap()`](0https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.ImageryLayer.colormap) was not used for tiles only services
# * [`Raster`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#raster)
# * [`RasterCollection`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#rastercollection)
#   * Fixes [`select_bands()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterCollection.select_bands) error **AttributeError:** _'RasterCollection' object has no attribute '_ras_coll_engine_obj'_
#   * Fixes issues with [`mosaic()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#arcgis.raster.RasterCollection.mosaic) method
#   * Fixes issues with applying or calling operations on individual `raster` objects from a `RasterCollection` created  from an [`ImageryLayer`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc/#imagerylayer) that was the output of [`create_image_collection()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#create-image-collection) in ArcGIS Online
# #### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/)
# * [`create_image_collection()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#create-image-collection)
# * [`copy_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#copy-raster)
# * [`manage_multidimensional_raster()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics/#manage-multidimensional-raster)
# #### [`arcgis.geoanalytics`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.toc/)
# * [`analyze_patterns`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#)
#   * Fixes `AttributeError` for [`find_point_clusters()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#find-point-clusters) from improperly formatted request
#   * Fixes issue with [`forest()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.analyze_patterns/#forest) method not handling response results correctly
# * [`find_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#)
#   * Fixes [`geocode_locations`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.find_locations/#geocode-locations) to properly send the `country` parameter
#   * Fixes issue with [`run_python_script()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.manage_data/#run-python-script) tool not properly passing `code` argument
# * [`summarize_data`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/)
#   * Fixes error with [`aggregate_points()`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data/#aggregate-points) when using `bins` as the aggregation type
# #### [`arcgis.geocoding`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#get-geocoders)
# * Modifies internal workings of [`batch_geocode()`](https://developers.arcgis.com/python/api-reference/arcgis.geocoding/#batch-geocode) to handle large tables
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/)
# * [`Data Preparation Methods`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#data-preparation-methods)
#   * Fixes `ValueError` when [`prepare_tabulardata()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-tabulardata) is run with a string as the `variable_predict` argument
# * [`Object Classification Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-classification-models)
#   * Fixes `AttributeError: _is_multispectral` when using [`FeatureClassifier(backend='tensorflow')`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#featureclassifier) and a `DataBunch` created outside of the ArcGIS Platform
# * [`Feature, Tabular and TimeSeries Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#feature-tabular-and-timeseries-models)
#   * [`MLModel`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel)
#     * Fixes missing `publish` parameter in [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.save) method
#     * Fixes errors with [`show_results()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.show_results) and `data.show_batch()` when used with dataframe obtained using train_test_split from `sklearn`
#     * Fixes error with [`predict()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.MLModel.predict) not publishing if `prediction_type=raster`
# * [`PixelClassfication`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pixel-classification-models)
#   * [`ConnectNet`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#connectnet)
#     * Fixes failure to return the mean IOU when loading [`from_model()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.ConnectNet.from_model) without `data` parameter
#   * [`MultiTaskRoadExtractor`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#multitaskroadextractor)
# * [`Object Detection Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-detection-models)
#     * [`MaskRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#maskrcnn)
#     * [`FasterRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#fasterrcnn)
#   * [`YOLOv3`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#yolov3)
#   * [`FasterRCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#fasterrcnn)
#     * Fixes `AttributeError` failures when running [`fit(tensorboard=True)`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.FasterRCNN.fit)
# * [`Object Tracking Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#object-tracking-models)
#   * [`SiamMask`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#siammask)
#     * Fixes issue when running [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) on Linux
# * [`3D Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#d-models)
#   * [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pointcnn)
#     * Fixes remapping issue in the [`predict_h5()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.predict_h5) method when used with output from [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#prepare-data) with `remap_classes` and `background_classcodes` arguments, and then exported by the API
# * [`Image Translation Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#image-translation-models)
#    * [`CycleGAN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#cyclegan)
#    * [`Pix2Pix`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pix2pix)
#   * [`CycleGAN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#cyclegan)
#       * calling [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.CycleGAN.fit) directly after [`lr_find()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.CycleGAN.lr_find)
#       * calling [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.CycleGAN.fit) 2 or more times on the same model
#   * [`Pix2Pix`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#pix2pix)
#     * Fixes error with [`fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.Pix2Pix.fit) method
#     * Removes incorrect `accuracy` parameter from [`compute_metrics()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.Pix2Pix.compute_metrics)
# * [`3D Models`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#d-models)
#   * Fixes `ValueError` when running [`fit(`tensorboard=True`)`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.PointCNN.fit) because of `plotly orca` dependency
# * [`Scanned Maps`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#scanned-maps)
#   * [`ScannedMapDigitizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#scannedmapdigitizer)
#       * `color_list` parameter in [`create_mask()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.ScannedMapDigitizer.create_mask) method
#       * `kernel_size` parameter in [`create_template_image()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.ScannedMapDigitizer.create_template_image) method
#       * `color` parameter in [`prepare_search_region()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc/#arcgis.learn.ScannedMapDigitizer.prepare_search_region)
