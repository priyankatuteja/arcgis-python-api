# %% [markdown]
# # PM2.5 prediction on big data using pyspark and facebook model

# %% [markdown]
# ## Table of Contents
# * [Introduction](#Introduction)
# * [Necessary imports](#Necessary-imports)
# * [Connect to your ArcGIS Enterprise organization](#Connect-to-your-ArcGIS-Enterprise-organization)
# * [Ensure your GIS supports GeoAnalytics](#Ensure-your-GIS-supports-GeoAnalytics)
# * [Create a big data file share](#Create-a-big-data-file-share)
# * [Get data for analysis](#Get-data-for-analysis)
#     * [Search for big data file shares](#Search-for-big-data-file-shares)
#     * [Search for feature layers](#Search-for-feature-layers)
# * [Describe data](#Describe-data)
#  ..fill it
# * [Conclusion](#Conclusion)

# %% [markdown]
# ## Introduction

# %%
intro lines

# %% [markdown]
# ## Necessary imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from datetime import datetime as dt
import pandas as pd

import arcgis
from arcgis.gis import GIS
from arcgis.geoanalytics.manage_data import run_python_script

# %% [markdown]
# ## Connect to your ArcGIS Enterprise organization

# %%
gis = GIS(profile="your_enterprise_portal")

# %% [markdown]
# ## Ensure your GIS supports GeoAnalytics
# After connecting to Enterprise portal, we need to ensure an ArcGIS Enterprise GIS is set up with a licensed GeoAnalytics server. To do so, we will call the `is_supported()` method.

# %%
arcgis.geoanalytics.is_supported()
# Out:
# True

# %% [markdown]
# ## Prepare the data
# To register a file share or an HDFS, we need to format datasets as subfolders within a single parent folder and register the parent folder. This parent folder becomes a datastore, and each subfolder becomes a dataset. Our folder hierarchy would look like below:

# %% [raw]
# |---FileShareFolder                 < -- The top-level folder is what is registered as a big data file share
#    |---air_quality_data                       < -- A folder "air_quality_data", composed of sub folders
#       |---2017                      < -- A folder "2017", composed of multiple csv
#          |---hourly_42101_2017.csv
#          |---hourly_42401_2017.csv
#          ....
#          ....
#          |---hourly_WIND_2017.csv
#       |---2018
#          |---hourly_42101_2018.csv
#          |---hourly_42401_2017.csv
#          ....
#          ....
#          |---hourly_WIND_2018.csv
#
#       |---2019
#          |---hourly_42401_2017.csv
#          ....
#          ....
#          |---hourly_WIND_2019.csv

# %% [markdown]
# Learn more about preparing your big data file share datasets [here](https://enterprise.arcgis.com/en/server/latest/get-started/windows/what-is-a-big-data-file-share.htm)

# %% [markdown]
# The `get_datastores()` method of the geoanalytics module returns a `DatastoreManager` object that lets you search for and manage the big data file share items as Python API `Datastore` objects on your GeoAnalytics server.

# %%
bigdata_datastore_manager = arcgis.geoanalytics.get_datastores()
bigdata_datastore_manager
# Out:
# <DatastoreManager for https://deldevld016.esri.com:6443/arcgis/admin>

# %% [markdown]
# We will register air quality data as a big data file share using the `add_bigdata()` function on a `DatastoreManager` object.
#
# When we register a directory, all subdirectories under the specified folder are also registered with the server. Always register the parent folder (for example, \\machinename\mydatashare) that contains one or more individual dataset folders as the big data file share item. To learn more, see [register a big data file share](https://enterprise.arcgis.com/en/server/latest/manage-data/windows/registering-your-data-with-arcgis-server-using-manager.htm#ESRI_SECTION1_0D55682C9D6E48E7857852A9E2D5D189)
#
# Note:
# You cannot browse directories in ArcGIS Server Manager. You must provide the full path to the folder you want to register, for example, \\myserver\share\bigdata. Avoid using local paths, such as C:\bigdata, unless the same data folder is available on all nodes of the server site.

# %%
data_item = bigdata_datastore_manager.add_bigdata("Air_Auality_17_18_19", r"/mnt/network/data")
# Out:
# Created Big Data file share for Air_Auality_17_18_19

# %%
bigdata_fileshares = bigdata_datastore_manager.search()
bigdata_fileshares
# Out:
# [<Datastore title:"/nosqlDatabases/AGSDataStore_nosqldb_tcs_d3fjluut" type:"nosql">,
#  <Datastore title:"/nosqlDatabases/AGSDataStore_bigdata_bds_1bpq1uya" type:"nosql">,
#  <Datastore title:"/enterpriseDatabases/AGSDataStore_ds_1hn1zqxt" type:"egdb">,
#  <Datastore title:"/bigDataFileShares/air_quality_17_18_19Full" type:"bigDataFileShare">,
#  <Datastore title:"/bigDataFileShares/air_quality_2019" type:"bigDataFileShare">,
#  <Datastore title:"/bigDataFileShares/air_quality" type:"bigDataFileShare">,
#  <Datastore title:"/bigDataFileShares/air_quality_17_18_19" type:"bigDataFileShare">,
#  <Datastore title:"/bigDataFileShares/Air_Auality_17_18_19" type:"bigDataFileShare">,
#  <Datastore title:"/bigDataFileShares/Chicago_Crime_2001_2020" type:"bigDataFileShare">]

# %% [markdown]
# ## Get data for analysis

# %% [markdown]
# Adding a big data file share to the Geoanalytics server adds a corresponding [big data file share item](https://enterprise.arcgis.com/en/portal/latest/use/what-is-a-big-data-file-share.htm) on the portal. We can search for these types of items using the item_type parameter.

# %%
search_result = gis.content.search("bigDataFileShares_Air_Auality_17_18_19", item_type = "big data file share", max_items=40)
search_result
# Out:
# [<Item title:"bigDataFileShares_Air_Auality_17_18_19" type:Big Data File Share owner:admin>]

# %%
air_item = search_result[0]

# %%
air_lyr = air_item.layers[0]

# %%
air_lyr.properties
# Out:
# {
#   "dataStoreID": "1aa144a0-a039-4e07-9c81-bc3c4efa4267",
#   "fields": [
#     {
#       "name": "State Code",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "County Code",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "Site Num",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "Parameter Code",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "POC",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "Latitude",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "Longitude",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "Datum",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Parameter Name",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Date Local",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Time Local",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Date GMT",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Time GMT",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Sample Measurement",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "Units of Measure",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "MDL",
#       "type": "esriFieldTypeDouble"
#     },
#     {
#       "name": "Uncertainty",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Qualifier",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Method Type",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Method Code",
#       "type": "esriFieldTypeInteger"
#     },
#     {
#       "name": "Method Name",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "State Name",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "County Name",
#       "type": "esriFieldTypeString"
#     },
#     {
#       "name": "Date of Last Change",
#       "type": "esriFieldTypeString"
#     }
#   ],
#   "name": "air_quality",
#   "geometryType": "esriGeometryPoint",
#   "type": "featureClass",
#   "spatialReference": {
#     "wkid": 4326
#   },
#   "geometry": {
#     "fields": [
#       {
#         "name": "Longitude",
#         "formats": [
#           "x"
#         ]
#       },
#       {
#         "name": "Latitude",
#         "formats": [
#           "y"
#         ]
#       }
#     ]
#   },
#   "time": {
#     "timeType": "instant",
#     "timeReference": {
#       "timeZone": "UTC"
#     },
#     "fields": [
#       {
#         "name": "Date Local",
#         "formats": [
#           "yyyy-MM-dd"
#         ]
#       }
#     ]
#   },
#   "currentVersion": 10.8,
#   "children": []
# }

# %% [markdown]
# Querying the layers property of the [item](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#item) returns a featureLayer representing the data. The object is actually an API Layer object.

# %%
usa_counties = gis.content.search('usacounties', 'feature layer')[0]

# %%
usa_counties
# Out:
# <Item title:"usaCounties" type:Feature Layer Collection owner:admin>

# %% [markdown]
# We will use the first item for our analysis. Since the item is a Feature Layer Collection, accessing the layers property will give us a list of Feature layer objects.

# %%
usa_counties_lyr = usa_counties.layers[0]

# %% [markdown]
# ## Describe data

# %% [markdown]
# The [`describe_dataset`](https://developers.arcgis.com/python/api-reference/arcgis.geoanalytics.summarize_data.html#describe-dataset) method provides an overview of big data. By default, the tool outputs a [table](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#table) layer containing calculated field statistics and a dict outlining geometry and time settings for the input layer.
#
# Optionally, the tool can output a ``feature layer`` representing a sample set of features using the ``sample_size`` parameter, or a single polygon feature layer representing the input feature layers' extent by setting the ``extent_output`` parameter to True.

# %%
from arcgis.geoanalytics.summarize_data import describe_dataset

# %%
description = describe_dataset(input_layer=air_lyr,
                               extent_output=True,
                               sample_size=1000,
                               output_name="Description of air quality data" + str(dt.now().microsecond),
                               return_tuple=True)

# %%
description.output_json
# Out:
# {'datasetName': 'air_quality',
#  'datasetSource': 'Big Data File Share - Air_Auality_17_18_19',
#  'recordCount': 147535365,
#  'geometry': {'geometryType': 'Point',
#   'sref': {'wkid': 4326},
#   'countNonEmpty': 147535365,
#   'countEmpty': 0,
#   'spatialExtent': {'xmin': -161.767,
#    'ymin': 17.953006,
#    'xmax': -65.915482,
#    'ymax': 64.84568999999999}},
#  'time': {'timeType': 'Instant',
#   'countNonEmpty': 147535365,
#   'countEmpty': 0,
#   'temporalExtent': {'start': '2017-01-01 00:00:00.000',
#    'end': '2019-04-30 00:00:00.000'}}}

# %%
description.sample_layer.query().sdf
# Out:
#      State_Code  County_Code  Site_Num  Parameter_Code  POC   Latitude  \
# 0            56           35       700           62201    1  42.486361
# 1             9            9        27           88313    1  41.301400
# 2            45           79         7           42601    2  34.093959
# 3            48          183         1           62101    1  32.378682
# 4            19          153        30           44201    1  41.603159
# ..          ...          ...       ...             ...  ...        ...
# 995          27           53       962           61104    1  44.965242
# 996          48           43       101           44201    1  29.302650
# 997          19          163        17           62101    1  41.467236
# 998          39          145        21           62101    1  38.600611
# 999           6           31         4           61103    1  36.102244
#
#       Longitude  Datum                Parameter_Name  Date_Local  ...  \
# 0   -110.098861  WGS84             Relative Humidity  2017-07-05  ...
# 1    -72.902871  WGS84  Black Carbon PM2.5 at 880 nm  2017-06-08  ...
# 2    -80.962304  WGS84             Nitric oxide (NO)  2018-06-28  ...
# 3    -94.711811  WGS84           Outdoor Temperature  2018-10-18  ...
# 4    -93.643118  WGS84                         Ozone  2017-12-23  ...
# ..          ...    ...                           ...         ...  ...
# 995  -93.254759  NAD83    Wind Direction - Resultant  2018-07-15  ...
# 996 -103.177810  WGS84                         Ozone  2018-02-21  ...
# 997  -90.688451  WGS84           Outdoor Temperature  2017-07-16  ...
# 998  -82.829782  NAD83           Outdoor Temperature  2017-12-20  ...
# 999 -119.565650  NAD83        Wind Speed - Resultant  2017-09-28  ...
#
#     Method_Type Method_Code  \
# 0       Non-FRM          60
# 1       Non-FRM         894
# 2       Non-FRM         674
# 3       Non-FRM          40
# 4           FEM          47
# ..          ...         ...
# 995     Non-FRM          63
# 996         FEM          47
# 997     Non-FRM          40
# 998     Non-FRM          40
# 999     Non-FRM          20
#
#                                            Method_Name      State_Name  \
# 0             Instrumental - Vaisala 435C RH/AT Sensor         Wyoming
# 1    Magee AE33/ TAPI M633 Aethalometer - Optical a...     Connecticut
# 2    Instrumental - Chemiluminescence Thermo Electr...  South Carolina
# 3            INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.           Texas
# 4                          INSTRUMENTAL - ULTRA VIOLET            Iowa
# ..                                                 ...             ...
# 995                        Instrumental - Climatronics       Minnesota
# 996                        INSTRUMENTAL - ULTRA VIOLET           Texas
# 997          INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.            Iowa
# 998          INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.            Ohio
# 999                    INSTRUMENTAL - VECTOR SUMMATION      California
#
#     County_Name  Date_of_Last_Change INSTANT_DATETIME  \
# 0      Sublette           2017-11-20       2017-07-05
# 1     New Haven           2018-01-09       2017-06-08
# 2      Richland           2019-02-18       2018-06-28
# 3         Gregg           2019-02-18       2018-10-18
# 4          Polk           2018-01-12       2017-12-23
# ..          ...                  ...              ...
# 995    Hennepin           2019-01-17       2018-07-15
# 996    Brewster           2018-04-19       2018-02-21
# 997       Scott           2017-08-10       2017-07-16
# 998      Scioto           2018-01-12       2017-12-20
# 999       Kings           2018-03-05       2017-09-28
#
#                                    globalid OBJECTID  \
# 0    {4CB48700-32CB-6126-E342-B783681A14AF}        1
# 1    {3D99EDC1-EC50-6B1A-508F-A0034CD9DB02}        2
# 2    {04ED8FBB-2ADF-AA44-BE30-F61E7A939657}        3
# 3    {60E09F2E-891F-EEBD-1253-0FFA407BDEA4}        4
# 4    {73E73030-0883-7A32-ED9C-BD59ACC00A2F}        5
# ..                                      ...      ...
# 995  {61736B2D-7C20-DF9E-37BA-21CF788F8FDD}     1003
# 996  {E739DA0C-7A97-8059-72A3-6505490F990D}     1004
# 997  {1B805C6B-7621-B9B2-9C25-E35DC16D466E}     1006
# 998  {965A3811-00DB-88A4-A734-959041D2CF67}     1007
# 999  {85F9DBB0-C17B-A74A-2717-29AACFCDB63B}     1008
#
#                                                  SHAPE
# 0    {"x": -110.098861, "y": 42.486360999999995, "s...
# 1    {"x": -72.90287099999999, "y": 41.3014, "spati...
# 2    {"x": -80.962304, "y": 34.093959, "spatialRefe...
# 3    {"x": -94.711811, "y": 32.378682, "spatialRefe...
# 4    {"x": -93.643118, "y": 41.603159, "spatialRefe...
# ..                                                 ...
# 995  {"x": -93.25475899999999, "y": 44.965241999999...
# 996  {"x": -103.17781, "y": 29.30265, "spatialRefer...
# 997  {"x": -90.688451, "y": 41.467236, "spatialRefe...
# 998  {"x": -82.829782, "y": 38.600611, "spatialRefe...
# 999  {"x": -119.56565, "y": 36.102244, "spatialRefe...
#
# [1000 rows x 28 columns]

# %%
m1 = gis.map()
m1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-e18d7446-7367-4977-970c-b63f4e002778"><img src=""></img></div>

# %%
m1.add_layer(description.sample_layer)

# %%
m1.zoom_to_layer(description.sample_layer)

# %%
m1.legend = False

# %%
def measurement_type():
    from datetime import datetime as dt
    # Load the big data file share layer into a DataFrame
    df = layers[0]
    out = df.groupBy('Method Name','Parameter Name').count()
    out.write.format("webgis").save("common_method_type" + str(dt.now().microsecond))

# %%
run_python_script(code=measurement_type, layers=[air_lyr])
# Out:
# [{'type': 'esriJobMessageTypeInformative',
#   'description': 'Executing (RunPythonScript): RunPythonScript "def measurement_type():\\n    from datetime import datetime as dt\\n    # Load the big data file share layer into a DataFrame\\n    df = layers[0]\\n    out = df.groupBy(\'Method Name\',\'Parameter Name\').count()\\n    out.write.format("webgis").save("common_method_type" + str(dt.now().microsecond))\\n\\nmeasurement_type()" https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_Air_Auality_17_18_19/BigDataCatalogServer/air_quality "{"defaultAggregationStyles": false}"'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Start Time: Thu Jul  2 21:58:58 2020'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Using URL based GPRecordSet param: https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_Air_Auality_17_18_19/BigDataCatalogServer/air_quality'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 1347 tasks.","params":{"totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"0/1347 distributed tasks completed.","params":{"completedTasks":"0","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1/1347 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"28/1347 distributed tasks completed.","params":{"completedTasks":"28","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"54/1347 distributed tasks completed.","params":{"completedTasks":"54","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"88/1347 distributed tasks completed.","params":{"completedTasks":"88","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"123/1347 distributed tasks completed.","params":{"completedTasks":"123","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"165/1347 distributed tasks completed.","params":{"completedTasks":"165","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"186/1347 distributed tasks completed.","params":{"completedTasks":"186","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"210/1347 distributed tasks completed.","params":{"completedTasks":"210","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"232/1347 distributed tasks completed.","params":{"completedTasks":"232","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"249/1347 distributed tasks completed.","params":{"completedTasks":"249","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"274/1347 distributed tasks completed.","params":{"completedTasks":"274","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"297/1347 distributed tasks completed.","params":{"completedTasks":"297","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"324/1347 distributed tasks completed.","params":{"completedTasks":"324","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"360/1347 distributed tasks completed.","params":{"completedTasks":"360","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"379/1347 distributed tasks completed.","params":{"completedTasks":"379","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"420/1347 distributed tasks completed.","params":{"completedTasks":"420","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"463/1347 distributed tasks completed.","params":{"completedTasks":"463","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"485/1347 distributed tasks completed.","params":{"completedTasks":"485","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"506/1347 distributed tasks completed.","params":{"completedTasks":"506","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"528/1347 distributed tasks completed.","params":{"completedTasks":"528","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"554/1347 distributed tasks completed.","params":{"completedTasks":"554","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"581/1347 distributed tasks completed.","params":{"completedTasks":"581","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"608/1347 distributed tasks completed.","params":{"completedTasks":"608","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"634/1347 distributed tasks completed.","params":{"completedTasks":"634","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"660/1347 distributed tasks completed.","params":{"completedTasks":"660","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"685/1347 distributed tasks completed.","params":{"completedTasks":"685","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"706/1347 distributed tasks completed.","params":{"completedTasks":"706","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"729/1347 distributed tasks completed.","params":{"completedTasks":"729","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"756/1347 distributed tasks completed.","params":{"completedTasks":"756","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"776/1347 distributed tasks completed.","params":{"completedTasks":"776","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"795/1347 distributed tasks completed.","params":{"completedTasks":"795","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"837/1347 distributed tasks completed.","params":{"completedTasks":"837","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"862/1347 distributed tasks completed.","params":{"completedTasks":"862","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"883/1347 distributed tasks completed.","params":{"completedTasks":"883","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"910/1347 distributed tasks completed.","params":{"completedTasks":"910","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"927/1347 distributed tasks completed.","params":{"completedTasks":"927","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"943/1347 distributed tasks completed.","params":{"completedTasks":"943","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"969/1347 distributed tasks completed.","params":{"completedTasks":"969","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"988/1347 distributed tasks completed.","params":{"completedTasks":"988","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1004/1347 distributed tasks completed.","params":{"completedTasks":"1004","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1027/1347 distributed tasks completed.","params":{"completedTasks":"1027","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1055/1347 distributed tasks completed.","params":{"completedTasks":"1055","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1067/1347 distributed tasks completed.","params":{"completedTasks":"1067","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1091/1347 distributed tasks completed.","params":{"completedTasks":"1091","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1118/1347 distributed tasks completed.","params":{"completedTasks":"1118","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1148/1347 distributed tasks completed.","params":{"completedTasks":"1148","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1347/1347 distributed tasks completed.","params":{"completedTasks":"1347","totalTasks":"1347"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101081","message":"Finished writing results:"}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101082","message":"* Count of features = 338","params":{"resultCount":"338"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101083","message":"* Spatial extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101084","message":"* Temporal extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101226","message":"Feature service layer created: https://deldevld016.esri.com/server/rest/services/Hosted/common_method_type121955/FeatureServer/0","params":{"serviceUrl":"https://deldevld016.esri.com/server/rest/services/Hosted/common_method_type121955/FeatureServer/0"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Succeeded at Thu Jul  2 22:05:03 2020 (Elapsed Time: 6 minutes 4 seconds)'}]

# %%
method_item = gis.content.search('common_method_type')[0]

# %%
method_df = method_item.tables[0].query(as_df=True)

# %%
method_df.sort_values(by='count', ascending=False)
# Out:
#                                            Method_Name  \
# 89              INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 6            INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.
# 158                        INSTRUMENTAL - ULTRA VIOLET
# 290                    INSTRUMENTAL - VECTOR SUMMATION
# 277                    INSTRUMENTAL - VECTOR SUMMATION
# ..                                                 ...
# 100  Cooper Environmental Services model Xact 620 -...
# 234  Cooper Environmental Services model Xact 620 -...
# 245  Cooper Environmental Services model Xact 620 -...
# 12   Cooper Environmental Services model Xact 620 -...
# 38                                                 The
#
#                  Parameter_Name     count  \
# 89                        Ozone  10650047
# 6           Outdoor Temperature   9808818
# 158                       Ozone   8634142
# 290  Wind Direction - Resultant   7348868
# 277      Wind Speed - Resultant   7267098
# ..                          ...       ...
# 100            Vanadium PM10 LC       105
# 234                 Tin PM10 LC       105
# 245              Silver PM10 LC       105
# 12              Calcium PM10 LC       105
# 38     PM2.5 - Local Conditions         1
#
#                                    globalid  OBJECTID
# 89   {1C333EB9-AB7D-9ACF-3116-09924757FD90}       112
# 6    {17DCDDD0-079F-5BF2-45C3-0BF485355EB0}         8
# 158  {EDA2D065-CE9E-2175-F094-8D9C2F6DCEBD}       198
# 290  {7154F73E-775C-4C1A-8775-FB99B0074348}       503
# 277  {4CCC027A-BABE-DF05-FC6B-9B04F013AF14}       455
# ..                                      ...       ...
# 100  {ABFA136A-BE6E-79A7-FCA4-608CFABCB77F}       126
# 234  {A5B11059-6FD5-EC9A-65E4-6D4B06B25FFF}       339
# 245  {E56280AE-5F42-AD31-2D95-C3418CB40985}       356
# 12   {6FC4B1BA-A7E4-A69C-BB44-CC26A6FD935B}        17
# 38   {E955A26F-4FC1-E8A3-40F1-D85F48D15ED9}        49
#
# [338 rows x 5 columns]

# %% [markdown]
# ## Average PM 2.5 value by County

# %%
def average():
    from datetime import datetime as dt
    df = layers[0]
    df = df.filter(df['Parameter Name'] == 'PM2.5 - Local Conditions')
    res = geoanalytics.join_features(target_layer=layers[1], 
                                     join_layer=df, 
                                     join_operation="JoinOneToOne",
                                     summary_fields=[{'statisticType' : 'mean', 'onStatisticField' : 'Sample Measurement'}],
                                     spatial_relationship='Contains')
    res.write.format("webgis").save("average_pm_by_county" + str(dt.now().microsecond))

# %%
run_python_script(average, [air_lyr, usa_counties_lyr])
# Out:
# [{'type': 'esriJobMessageTypeInformative',
#   'description': 'Executing (RunPythonScript): RunPythonScript "def average():\\n    from datetime import datetime as dt\\n    df = layers[0]\\n    df = df.filter(df[\'Parameter Name\'] == \'PM2.5 - Local Conditions\')\\n    res = geoanalytics.join_features(target_layer=layers[1], \\n                                     join_layer=df, \\n                                     join_operation="JoinOneToOne",\\n                                     summary_fields=[{\'statisticType\' : \'mean\', \'onStatisticField\' : \'Sample Measurement\'}],\\n                                     spatial_relationship=\'Contains\')\\n    res.write.format("webgis").save("average_pm_by_county" + str(dt.now().microsecond))\\n\\naverage()" https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_Air_Auality_17_18_19/BigDataCatalogServer/air_quality;https://deldevld016.esri.com/server/rest/services/Hosted/usaCounties/FeatureServer/0 "{"defaultAggregationStyles": false}"'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Start Time: Thu Jul  2 22:27:10 2020'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Using URL based GPRecordSet param: https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_Air_Auality_17_18_19/BigDataCatalogServer/air_quality'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Using URL based GPRecordSet param: https://deldevld016.esri.com/server/rest/services/Hosted/usaCounties/FeatureServer/0'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 3441 tasks.","params":{"totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"0/3441 distributed tasks completed.","params":{"completedTasks":"0","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1/3441 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"29/3441 distributed tasks completed.","params":{"completedTasks":"29","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"57/3441 distributed tasks completed.","params":{"completedTasks":"57","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"82/3441 distributed tasks completed.","params":{"completedTasks":"82","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"106/3441 distributed tasks completed.","params":{"completedTasks":"106","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"130/3441 distributed tasks completed.","params":{"completedTasks":"130","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"150/3441 distributed tasks completed.","params":{"completedTasks":"150","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"181/3441 distributed tasks completed.","params":{"completedTasks":"181","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"196/3441 distributed tasks completed.","params":{"completedTasks":"196","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"221/3441 distributed tasks completed.","params":{"completedTasks":"221","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"240/3441 distributed tasks completed.","params":{"completedTasks":"240","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"265/3441 distributed tasks completed.","params":{"completedTasks":"265","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"292/3441 distributed tasks completed.","params":{"completedTasks":"292","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"305/3441 distributed tasks completed.","params":{"completedTasks":"305","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"329/3441 distributed tasks completed.","params":{"completedTasks":"329","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"350/3441 distributed tasks completed.","params":{"completedTasks":"350","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"374/3441 distributed tasks completed.","params":{"completedTasks":"374","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"397/3441 distributed tasks completed.","params":{"completedTasks":"397","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"421/3441 distributed tasks completed.","params":{"completedTasks":"421","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"444/3441 distributed tasks completed.","params":{"completedTasks":"444","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"462/3441 distributed tasks completed.","params":{"completedTasks":"462","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"487/3441 distributed tasks completed.","params":{"completedTasks":"487","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"516/3441 distributed tasks completed.","params":{"completedTasks":"516","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"544/3441 distributed tasks completed.","params":{"completedTasks":"544","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"569/3441 distributed tasks completed.","params":{"completedTasks":"569","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"592/3441 distributed tasks completed.","params":{"completedTasks":"592","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"618/3441 distributed tasks completed.","params":{"completedTasks":"618","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"643/3441 distributed tasks completed.","params":{"completedTasks":"643","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"672/3441 distributed tasks completed.","params":{"completedTasks":"672","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"689/3441 distributed tasks completed.","params":{"completedTasks":"689","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"712/3441 distributed tasks completed.","params":{"completedTasks":"712","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"732/3441 distributed tasks completed.","params":{"completedTasks":"732","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"774/3441 distributed tasks completed.","params":{"completedTasks":"774","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"800/3441 distributed tasks completed.","params":{"completedTasks":"800","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"838/3441 distributed tasks completed.","params":{"completedTasks":"838","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"865/3441 distributed tasks completed.","params":{"completedTasks":"865","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"890/3441 distributed tasks completed.","params":{"completedTasks":"890","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"917/3441 distributed tasks completed.","params":{"completedTasks":"917","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"933/3441 distributed tasks completed.","params":{"completedTasks":"933","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"958/3441 distributed tasks completed.","params":{"completedTasks":"958","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"984/3441 distributed tasks completed.","params":{"completedTasks":"984","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1009/3441 distributed tasks completed.","params":{"completedTasks":"1009","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1030/3441 distributed tasks completed.","params":{"completedTasks":"1030","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1058/3441 distributed tasks completed.","params":{"completedTasks":"1058","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1078/3441 distributed tasks completed.","params":{"completedTasks":"1078","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1107/3441 distributed tasks completed.","params":{"completedTasks":"1107","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1134/3441 distributed tasks completed.","params":{"completedTasks":"1134","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"3441/3441 distributed tasks completed.","params":{"completedTasks":"3441","totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 3441 tasks.","params":{"totalTasks":"3441"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 13766 tasks.","params":{"totalTasks":"13766"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"0/13766 distributed tasks completed.","params":{"completedTasks":"0","totalTasks":"13766"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"5637/13766 distributed tasks completed.","params":{"completedTasks":"5637","totalTasks":"13766"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"8003/13766 distributed tasks completed.","params":{"completedTasks":"8003","totalTasks":"13766"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101081","message":"Finished writing results:"}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101082","message":"* Count of features = 440","params":{"resultCount":"440"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101083","message":"* Spatial extent = {\\"xmin\\":-178.3322386630926,\\"ymin\\":18.258825938798722,\\"xmax\\":-66.11848608585925,\\"ymax\\":63.482913038367414}","params":{"extent":"{\\"xmin\\":-178.3322386630926,\\"ymin\\":18.258825938798722,\\"xmax\\":-66.11848608585925,\\"ymax\\":63.482913038367414}"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101084","message":"* Temporal extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101226","message":"Feature service layer created: https://deldevld016.esri.com/server/rest/services/Hosted/average_pm_by_county63006/FeatureServer/0","params":{"serviceUrl":"https://deldevld016.esri.com/server/rest/services/Hosted/average_pm_by_county63006/FeatureServer/0"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Succeeded at Thu Jul  2 22:33:29 2020 (Elapsed Time: 6 minutes 19 seconds)'}]

# %%
res = run_python_script(average, [air_lyr, usa_counties_lyr])

# %%
average_pm_by_county = gis.content.search('average_pm_by_county')[0]

# %%
average_pm_by_county
# Out:
# <Item title:"average_pm_by_county63006" type:Feature Layer Collection owner:admin>

# %%
m2 = gis.map()
m2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-834f266c-b5d4-4fe8-a599-d99d8d26430e"><img src=""></img></div>

# %%
m2.add_layer(average_pm_by_county.layers[0])

# %%
m2.zoom_to_layer(average_pm_by_county.layers[0])

# %%
def data_processsing():
    from datetime import datetime as dt
    import pyspark.sql.functions as F
    from pyspark.sql.functions import concat, col, lit
    # Load the big data file share layer into a DataFrame.
    df = layers[0]
    cols = ['Site Num', 'County Code', 'State Code', 'Date Local', 'Time Local', 'Parameter Name', 'Sample Measurement']
    df = df.select(cols)
    df = df.withColumn('Site_Num', F.lpad(df['Site Num'], 4, '0'))
    df = df.withColumn('County_Code', F.lpad(df['County Code'], 3, '0'))
    df = df.withColumn('State_Code', F.lpad(df['State Code'], 2, '0'))
    df = df.withColumn('unique_id', F.concat(F.col('State_Code'), F.col('County_Code'), F.col('Site_Num')))
#     drop_cols = ['Site_Num', 'County_Code', 'State_Code', 'Site Num', 'County Code', 'State Code']
    df = df.drop('Site_Num', 'County_Code', 'Staate_Code', 'Site Num', 'County Code', 'State Code')
    df = df.withColumn('datetime', concat(col("Date Local"), lit(" "), col("Time Local")))
#     drop_cols = ['Time Local', 'Date Local']
    df = df.drop('Time Local', 'Date Local')
    df = df.filter(df.unique_id == df.first().unique_id)
    # group the dataframe by TextType field and count the number of calls for each call type. 
    df = df.groupby(df['datetime'], df['unique_id']).pivot("Parameter Name").avg("Sample Measurement")

    df.write.format("webgis").save("timeseries_data_17_18_19_1station" + str(dt.now().microsecond))

# %%
run_python_script(code=data_processsing, layers=[air_lyr], gis=gis)
# Out:
# Submitted.
# Executing...
# Executing (RunPythonScript): RunPythonScript "def data_processsing():\n    from datetime import datetime as dt\n    import pyspark.sql.functions as F\n    from pyspark.sql.functions import concat, col, lit\n    # Load the big data file share layer into a DataFrame.\n    df = layers[0]\n    cols = ['Site Num', 'County Code', 'State Code', 'Date Local', 'Time Local', 'Parameter Name', 'Sample Measurement']\n    df = df.select(cols)\n    df = df.withColumn('Site_Num', F.lpad(df['Site Num'], 4, '0'))\n    df = df.withColumn('County_Code', F.lpad(df['County Code'], 3, '0'))\n    df = df.withColumn('State_Code', F.lpad(df['State Code'], 2, '0'))\n    df = df.withColumn('unique_id', F.concat(F.col('State_Code'), F.col('County_Code'), F.col('Site_Num')))\n#     drop_cols = ['Site_Num', 'County_Code', 'State_Code', 'Site Num', 'County Code', 'State Code']\n    df = df.drop('Site_Num', 'County_Code', 'Staate_Code', 'Site Num', 'County Code', 'State Code')\n    df = df.withColumn('datetime', concat(col("Date Local"), lit(" "), col("Time Local")))\n#     drop_cols = ['Time Local', 'Date Local']\n    df = df.drop('Time Local', 'Date Local')\n    df = df.filter(df.unique_id == df.first().unique_id)\n    # group the dataframe by TextType field and count the number of calls for each call type. \n    df = df.groupby(df['datetime'], df['unique_id']).pivot("Parameter Name").avg("Sample Measurement")\n\n    df.write.format("webgis").save("timeseries_data_17_18_19_1station" + str(dt.now().microsecond))\n\ndata_processsing()" https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_air_quality_17_18_19Full/BigDataCatalogServer/air_quality "{"defaultAggregationStyles": false}"
# Start Time: Tue Jun 23 19:42:42 2020
# Using URL based GPRecordSet param: https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_air_quality_17_18_19Full/BigDataCatalogServer/air_quality
# {"messageCode":"BD_101028","message":"Starting new distributed job with 1 tasks.","params":{"totalTasks":"1"}}
# {"messageCode":"BD_101029","message":"0/1 distributed tasks completed.","params":{"completedTasks":"0","totalTasks":"1"}}
# {"messageCode":"BD_101029","message":"1/1 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1"}}
# {"messageCode":"BD_101028","message":"Starting new distributed job with 1348 tasks.","params":{"totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1/1348 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"26/1348 distributed tasks completed.","params":{"completedTasks":"26","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"62/1348 distributed tasks completed.","params":{"completedTasks":"62","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"79/1348 distributed tasks completed.","params":{"completedTasks":"79","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"92/1348 distributed tasks completed.","params":{"completedTasks":"92","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"111/1348 distributed tasks completed.","params":{"completedTasks":"111","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"132/1348 distributed tasks completed.","params":{"completedTasks":"132","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"156/1348 distributed tasks completed.","params":{"completedTasks":"156","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"179/1348 distributed tasks completed.","params":{"completedTasks":"179","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"202/1348 distributed tasks completed.","params":{"completedTasks":"202","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"219/1348 distributed tasks completed.","params":{"completedTasks":"219","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"239/1348 distributed tasks completed.","params":{"completedTasks":"239","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"273/1348 distributed tasks completed.","params":{"completedTasks":"273","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"279/1348 distributed tasks completed.","params":{"completedTasks":"279","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"303/1348 distributed tasks completed.","params":{"completedTasks":"303","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"326/1348 distributed tasks completed.","params":{"completedTasks":"326","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"350/1348 distributed tasks completed.","params":{"completedTasks":"350","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"366/1348 distributed tasks completed.","params":{"completedTasks":"366","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"382/1348 distributed tasks completed.","params":{"completedTasks":"382","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"421/1348 distributed tasks completed.","params":{"completedTasks":"421","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"443/1348 distributed tasks completed.","params":{"completedTasks":"443","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"459/1348 distributed tasks completed.","params":{"completedTasks":"459","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"477/1348 distributed tasks completed.","params":{"completedTasks":"477","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"515/1348 distributed tasks completed.","params":{"completedTasks":"515","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"536/1348 distributed tasks completed.","params":{"completedTasks":"536","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"557/1348 distributed tasks completed.","params":{"completedTasks":"557","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"577/1348 distributed tasks completed.","params":{"completedTasks":"577","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"605/1348 distributed tasks completed.","params":{"completedTasks":"605","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"619/1348 distributed tasks completed.","params":{"completedTasks":"619","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"655/1348 distributed tasks completed.","params":{"completedTasks":"655","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"682/1348 distributed tasks completed.","params":{"completedTasks":"682","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"704/1348 distributed tasks completed.","params":{"completedTasks":"704","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"723/1348 distributed tasks completed.","params":{"completedTasks":"723","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"749/1348 distributed tasks completed.","params":{"completedTasks":"749","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"784/1348 distributed tasks completed.","params":{"completedTasks":"784","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"805/1348 distributed tasks completed.","params":{"completedTasks":"805","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"840/1348 distributed tasks completed.","params":{"completedTasks":"840","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"872/1348 distributed tasks completed.","params":{"completedTasks":"872","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"883/1348 distributed tasks completed.","params":{"completedTasks":"883","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"911/1348 distributed tasks completed.","params":{"completedTasks":"911","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"922/1348 distributed tasks completed.","params":{"completedTasks":"922","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"941/1348 distributed tasks completed.","params":{"completedTasks":"941","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"968/1348 distributed tasks completed.","params":{"completedTasks":"968","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1004/1348 distributed tasks completed.","params":{"completedTasks":"1004","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1007/1348 distributed tasks completed.","params":{"completedTasks":"1007","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1024/1348 distributed tasks completed.","params":{"completedTasks":"1024","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1046/1348 distributed tasks completed.","params":{"completedTasks":"1046","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1065/1348 distributed tasks completed.","params":{"completedTasks":"1065","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1089/1348 distributed tasks completed.","params":{"completedTasks":"1089","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1115/1348 distributed tasks completed.","params":{"completedTasks":"1115","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1138/1348 distributed tasks completed.","params":{"completedTasks":"1138","totalTasks":"1348"}}
# {"messageCode":"BD_101029","message":"1348/1348 distributed tasks completed.","params":{"completedTasks":"1348","totalTasks":"1348"}}
# {"messageCode":"BD_101028","message":"Starting new distributed job with 1547 tasks.","params":{"totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1/1547 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"28/1547 distributed tasks completed.","params":{"completedTasks":"28","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"51/1547 distributed tasks completed.","params":{"completedTasks":"51","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"72/1547 distributed tasks completed.","params":{"completedTasks":"72","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"92/1547 distributed tasks completed.","params":{"completedTasks":"92","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"117/1547 distributed tasks completed.","params":{"completedTasks":"117","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"144/1547 distributed tasks completed.","params":{"completedTasks":"144","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"168/1547 distributed tasks completed.","params":{"completedTasks":"168","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"177/1547 distributed tasks completed.","params":{"completedTasks":"177","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"201/1547 distributed tasks completed.","params":{"completedTasks":"201","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"225/1547 distributed tasks completed.","params":{"completedTasks":"225","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"246/1547 distributed tasks completed.","params":{"completedTasks":"246","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"271/1547 distributed tasks completed.","params":{"completedTasks":"271","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"294/1547 distributed tasks completed.","params":{"completedTasks":"294","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"319/1547 distributed tasks completed.","params":{"completedTasks":"319","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"335/1547 distributed tasks completed.","params":{"completedTasks":"335","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"353/1547 distributed tasks completed.","params":{"completedTasks":"353","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"371/1547 distributed tasks completed.","params":{"completedTasks":"371","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"387/1547 distributed tasks completed.","params":{"completedTasks":"387","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"411/1547 distributed tasks completed.","params":{"completedTasks":"411","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"427/1547 distributed tasks completed.","params":{"completedTasks":"427","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"448/1547 distributed tasks completed.","params":{"completedTasks":"448","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"472/1547 distributed tasks completed.","params":{"completedTasks":"472","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"494/1547 distributed tasks completed.","params":{"completedTasks":"494","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"508/1547 distributed tasks completed.","params":{"completedTasks":"508","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"531/1547 distributed tasks completed.","params":{"completedTasks":"531","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"559/1547 distributed tasks completed.","params":{"completedTasks":"559","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"572/1547 distributed tasks completed.","params":{"completedTasks":"572","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"592/1547 distributed tasks completed.","params":{"completedTasks":"592","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"622/1547 distributed tasks completed.","params":{"completedTasks":"622","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"642/1547 distributed tasks completed.","params":{"completedTasks":"642","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"662/1547 distributed tasks completed.","params":{"completedTasks":"662","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"684/1547 distributed tasks completed.","params":{"completedTasks":"684","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"703/1547 distributed tasks completed.","params":{"completedTasks":"703","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"726/1547 distributed tasks completed.","params":{"completedTasks":"726","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"750/1547 distributed tasks completed.","params":{"completedTasks":"750","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"771/1547 distributed tasks completed.","params":{"completedTasks":"771","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"784/1547 distributed tasks completed.","params":{"completedTasks":"784","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"795/1547 distributed tasks completed.","params":{"completedTasks":"795","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"819/1547 distributed tasks completed.","params":{"completedTasks":"819","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"839/1547 distributed tasks completed.","params":{"completedTasks":"839","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"860/1547 distributed tasks completed.","params":{"completedTasks":"860","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"878/1547 distributed tasks completed.","params":{"completedTasks":"878","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"892/1547 distributed tasks completed.","params":{"completedTasks":"892","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"911/1547 distributed tasks completed.","params":{"completedTasks":"911","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"934/1547 distributed tasks completed.","params":{"completedTasks":"934","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"954/1547 distributed tasks completed.","params":{"completedTasks":"954","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"973/1547 distributed tasks completed.","params":{"completedTasks":"973","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"993/1547 distributed tasks completed.","params":{"completedTasks":"993","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1016/1547 distributed tasks completed.","params":{"completedTasks":"1016","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1033/1547 distributed tasks completed.","params":{"completedTasks":"1033","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1050/1547 distributed tasks completed.","params":{"completedTasks":"1050","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1071/1547 distributed tasks completed.","params":{"completedTasks":"1071","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1099/1547 distributed tasks completed.","params":{"completedTasks":"1099","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1124/1547 distributed tasks completed.","params":{"completedTasks":"1124","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1128/1547 distributed tasks completed.","params":{"completedTasks":"1128","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1348/1547 distributed tasks completed.","params":{"completedTasks":"1348","totalTasks":"1547"}}
# {"messageCode":"BD_101029","message":"1547/1547 distributed tasks completed.","params":{"completedTasks":"1547","totalTasks":"1547"}}
# {"messageCode":"BD_101081","message":"Finished writing results:"}
# {"messageCode":"BD_101082","message":"* Count of features = 18231","params":{"resultCount":"18231"}}
# {"messageCode":"BD_101083","message":"* Spatial extent = None","params":{"extent":"None"}}
# {"messageCode":"BD_101084","message":"* Temporal extent = None","params":{"extent":"None"}}
# {"messageCode":"BD_101226","message":"Feature service layer created: https://deldevld016.esri.com/server/rest/services/Hosted/timeseries_data_17_18_19_1station897490/FeatureServer/0","params":{"serviceUrl":"https://deldevld016.esri.com/server/rest/services/Hosted/timeseries_data_17_18_19_1station897490/FeatureServer/0"}}
# [{'type': 'esriJobMessageTypeInformative',
#   'description': 'Executing (RunPythonScript): RunPythonScript "def data_processsing():\\n    from datetime import datetime as dt\\n    import pyspark.sql.functions as F\\n    from pyspark.sql.functions import concat, col, lit\\n    # Load the big data file share layer into a DataFrame.\\n    df = layers[0]\\n    cols = [\'Site Num\', \'County Code\', \'State Code\', \'Date Local\', \'Time Local\', \'Parameter Name\', \'Sample Measurement\']\\n    df = df.select(cols)\\n    df = df.withColumn(\'Site_Num\', F.lpad(df[\'Site Num\'], 4, \'0\'))\\n    df = df.withColumn(\'County_Code\', F.lpad(df[\'County Code\'], 3, \'0\'))\\n    df = df.withColumn(\'State_Code\', F.lpad(df[\'State Code\'], 2, \'0\'))\\n    df = df.withColumn(\'unique_id\', F.concat(F.col(\'State_Code\'), F.col(\'County_Code\'), F.col(\'Site_Num\')))\\n#     drop_cols = [\'Site_Num\', \'County_Code\', \'State_Code\', \'Site Num\', \'County Code\', \'State Code\']\\n    df = df.drop(\'Site_Num\', \'County_Code\', \'Staate_Code\', \'Site Num\', \'County Code\', \'State Code\')\\n    df = df.withColumn(\'datetime\', concat(col("Date Local"), lit(" "), col("Time Local")))\\n#     drop_cols = [\'Time Local\', \'Date Local\']\\n    df = df.drop(\'Time Local\', \'Date Local\')\\n    df = df.filter(df.unique_id == df.first().unique_id)\\n    # group the dataframe by TextType field and count the number of calls for each call type. \\n    df = df.groupby(df[\'datetime\'], df[\'unique_id\']).pivot("Parameter Name").avg("Sample Measurement")\\n\\n    df.write.format("webgis").save("timeseries_data_17_18_19_1station" + str(dt.now().microsecond))\\n\\ndata_processsing()" https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_air_quality_17_18_19Full/BigDataCatalogServer/air_quality "{"defaultAggregationStyles": false}"'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Start Time: Tue Jun 23 19:42:42 2020'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Using URL based GPRecordSet param: https://deldevld016.esri.com/server/rest/services/DataStoreCatalogs/bigDataFileShares_air_quality_17_18_19Full/BigDataCatalogServer/air_quality'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 1 tasks.","params":{"totalTasks":"1"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"0/1 distributed tasks completed.","params":{"completedTasks":"0","totalTasks":"1"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1/1 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 1348 tasks.","params":{"totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1/1348 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"26/1348 distributed tasks completed.","params":{"completedTasks":"26","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"62/1348 distributed tasks completed.","params":{"completedTasks":"62","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"79/1348 distributed tasks completed.","params":{"completedTasks":"79","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"92/1348 distributed tasks completed.","params":{"completedTasks":"92","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"111/1348 distributed tasks completed.","params":{"completedTasks":"111","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"132/1348 distributed tasks completed.","params":{"completedTasks":"132","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"156/1348 distributed tasks completed.","params":{"completedTasks":"156","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"179/1348 distributed tasks completed.","params":{"completedTasks":"179","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"202/1348 distributed tasks completed.","params":{"completedTasks":"202","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"219/1348 distributed tasks completed.","params":{"completedTasks":"219","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"239/1348 distributed tasks completed.","params":{"completedTasks":"239","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"273/1348 distributed tasks completed.","params":{"completedTasks":"273","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"279/1348 distributed tasks completed.","params":{"completedTasks":"279","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"303/1348 distributed tasks completed.","params":{"completedTasks":"303","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"326/1348 distributed tasks completed.","params":{"completedTasks":"326","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"350/1348 distributed tasks completed.","params":{"completedTasks":"350","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"366/1348 distributed tasks completed.","params":{"completedTasks":"366","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"382/1348 distributed tasks completed.","params":{"completedTasks":"382","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"421/1348 distributed tasks completed.","params":{"completedTasks":"421","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"443/1348 distributed tasks completed.","params":{"completedTasks":"443","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"459/1348 distributed tasks completed.","params":{"completedTasks":"459","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"477/1348 distributed tasks completed.","params":{"completedTasks":"477","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"515/1348 distributed tasks completed.","params":{"completedTasks":"515","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"536/1348 distributed tasks completed.","params":{"completedTasks":"536","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"557/1348 distributed tasks completed.","params":{"completedTasks":"557","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"577/1348 distributed tasks completed.","params":{"completedTasks":"577","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"605/1348 distributed tasks completed.","params":{"completedTasks":"605","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"619/1348 distributed tasks completed.","params":{"completedTasks":"619","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"655/1348 distributed tasks completed.","params":{"completedTasks":"655","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"682/1348 distributed tasks completed.","params":{"completedTasks":"682","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"704/1348 distributed tasks completed.","params":{"completedTasks":"704","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"723/1348 distributed tasks completed.","params":{"completedTasks":"723","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"749/1348 distributed tasks completed.","params":{"completedTasks":"749","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"784/1348 distributed tasks completed.","params":{"completedTasks":"784","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"805/1348 distributed tasks completed.","params":{"completedTasks":"805","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"840/1348 distributed tasks completed.","params":{"completedTasks":"840","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"872/1348 distributed tasks completed.","params":{"completedTasks":"872","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"883/1348 distributed tasks completed.","params":{"completedTasks":"883","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"911/1348 distributed tasks completed.","params":{"completedTasks":"911","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"922/1348 distributed tasks completed.","params":{"completedTasks":"922","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"941/1348 distributed tasks completed.","params":{"completedTasks":"941","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"968/1348 distributed tasks completed.","params":{"completedTasks":"968","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1004/1348 distributed tasks completed.","params":{"completedTasks":"1004","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1007/1348 distributed tasks completed.","params":{"completedTasks":"1007","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1024/1348 distributed tasks completed.","params":{"completedTasks":"1024","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1046/1348 distributed tasks completed.","params":{"completedTasks":"1046","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1065/1348 distributed tasks completed.","params":{"completedTasks":"1065","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1089/1348 distributed tasks completed.","params":{"completedTasks":"1089","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1115/1348 distributed tasks completed.","params":{"completedTasks":"1115","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1138/1348 distributed tasks completed.","params":{"completedTasks":"1138","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1348/1348 distributed tasks completed.","params":{"completedTasks":"1348","totalTasks":"1348"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 1547 tasks.","params":{"totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1/1547 distributed tasks completed.","params":{"completedTasks":"1","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"28/1547 distributed tasks completed.","params":{"completedTasks":"28","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"51/1547 distributed tasks completed.","params":{"completedTasks":"51","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"72/1547 distributed tasks completed.","params":{"completedTasks":"72","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"92/1547 distributed tasks completed.","params":{"completedTasks":"92","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"117/1547 distributed tasks completed.","params":{"completedTasks":"117","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"144/1547 distributed tasks completed.","params":{"completedTasks":"144","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"168/1547 distributed tasks completed.","params":{"completedTasks":"168","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"177/1547 distributed tasks completed.","params":{"completedTasks":"177","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"201/1547 distributed tasks completed.","params":{"completedTasks":"201","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"225/1547 distributed tasks completed.","params":{"completedTasks":"225","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"246/1547 distributed tasks completed.","params":{"completedTasks":"246","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"271/1547 distributed tasks completed.","params":{"completedTasks":"271","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"294/1547 distributed tasks completed.","params":{"completedTasks":"294","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"319/1547 distributed tasks completed.","params":{"completedTasks":"319","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"335/1547 distributed tasks completed.","params":{"completedTasks":"335","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"353/1547 distributed tasks completed.","params":{"completedTasks":"353","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"371/1547 distributed tasks completed.","params":{"completedTasks":"371","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"387/1547 distributed tasks completed.","params":{"completedTasks":"387","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"411/1547 distributed tasks completed.","params":{"completedTasks":"411","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"427/1547 distributed tasks completed.","params":{"completedTasks":"427","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"448/1547 distributed tasks completed.","params":{"completedTasks":"448","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"472/1547 distributed tasks completed.","params":{"completedTasks":"472","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"494/1547 distributed tasks completed.","params":{"completedTasks":"494","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"508/1547 distributed tasks completed.","params":{"completedTasks":"508","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"531/1547 distributed tasks completed.","params":{"completedTasks":"531","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"559/1547 distributed tasks completed.","params":{"completedTasks":"559","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"572/1547 distributed tasks completed.","params":{"completedTasks":"572","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"592/1547 distributed tasks completed.","params":{"completedTasks":"592","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"622/1547 distributed tasks completed.","params":{"completedTasks":"622","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"642/1547 distributed tasks completed.","params":{"completedTasks":"642","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"662/1547 distributed tasks completed.","params":{"completedTasks":"662","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"684/1547 distributed tasks completed.","params":{"completedTasks":"684","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"703/1547 distributed tasks completed.","params":{"completedTasks":"703","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"726/1547 distributed tasks completed.","params":{"completedTasks":"726","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"750/1547 distributed tasks completed.","params":{"completedTasks":"750","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"771/1547 distributed tasks completed.","params":{"completedTasks":"771","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"784/1547 distributed tasks completed.","params":{"completedTasks":"784","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"795/1547 distributed tasks completed.","params":{"completedTasks":"795","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"819/1547 distributed tasks completed.","params":{"completedTasks":"819","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"839/1547 distributed tasks completed.","params":{"completedTasks":"839","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"860/1547 distributed tasks completed.","params":{"completedTasks":"860","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"878/1547 distributed tasks completed.","params":{"completedTasks":"878","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"892/1547 distributed tasks completed.","params":{"completedTasks":"892","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"911/1547 distributed tasks completed.","params":{"completedTasks":"911","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"934/1547 distributed tasks completed.","params":{"completedTasks":"934","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"954/1547 distributed tasks completed.","params":{"completedTasks":"954","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"973/1547 distributed tasks completed.","params":{"completedTasks":"973","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"993/1547 distributed tasks completed.","params":{"completedTasks":"993","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1016/1547 distributed tasks completed.","params":{"completedTasks":"1016","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1033/1547 distributed tasks completed.","params":{"completedTasks":"1033","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1050/1547 distributed tasks completed.","params":{"completedTasks":"1050","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1071/1547 distributed tasks completed.","params":{"completedTasks":"1071","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1099/1547 distributed tasks completed.","params":{"completedTasks":"1099","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1124/1547 distributed tasks completed.","params":{"completedTasks":"1124","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1128/1547 distributed tasks completed.","params":{"completedTasks":"1128","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1348/1547 distributed tasks completed.","params":{"completedTasks":"1348","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"1547/1547 distributed tasks completed.","params":{"completedTasks":"1547","totalTasks":"1547"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101081","message":"Finished writing results:"}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101082","message":"* Count of features = 18231","params":{"resultCount":"18231"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101083","message":"* Spatial extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101084","message":"* Temporal extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101226","message":"Feature service layer created: https://deldevld016.esri.com/server/rest/services/Hosted/timeseries_data_17_18_19_1station897490/FeatureServer/0","params":{"serviceUrl":"https://deldevld016.esri.com/server/rest/services/Hosted/timeseries_data_17_18_19_1station897490/FeatureServer/0"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Succeeded at Tue Jun 23 19:56:45 2020 (Elapsed Time: 14 minutes 2 seconds)'}]

# %%
data = gis.content.search('timeseries_data_17_18_19_1station_working')

# %%
data[0]
# Out:
# <Item title:"timeseries_data_17_18_19_1station_working" type:Table Layer owner:admin>

# %%
series_data = data[0].tables[0]

# %%
series_data.query().sdf.columns
# Out:
# Index(['datetime', 'unique_id', 'Barometric_pressure', 'Carbon_monoxide',
#        'Nitric_oxide__NO_', 'Nitrogen_dioxide__NO2_', 'Outdoor_Temperature',
#        'Oxides_of_nitrogen__NOx_', 'Ozone', 'PM10_Total_0_10um_STP',
#        'PM2_5___Local_Conditions', 'Reactive_oxides_of_nitrogen__NOy_',
#        'Relative_Humidity', 'Sulfur_dioxide', 'Wind_Direction___Resultant',
#        'Wind_Speed___Resultant', 'globalid', 'OBJECTID'],
#       dtype='object')

# %%
def predict_pm25():
    from arcgis.gis import GIS
    gis = GIS('https://deldevld016.esri.com/portal', 'admin', 'esri.agp2', profile="your_enterprise_portal", verify_cert=False)
    from datetime import datetime as dt
    from pyspark.sql.functions import concat, col, lit
    import pandas as pd
    import numpy as np
    from fbprophet import Prophet
    from pyspark.sql.functions import pandas_udf, PandasUDFType
    from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, FloatType, TimestampType
    import warnings
    warnings.filterwarnings('ignore')
    
    df1 = layers[0] 
    cols = ['Outdoor_Temperature', 'Ozone', 'PM10_Total_0_10um_STP',
        'PM2_5___Local_Conditions',
        'Wind_Direction___Resultant',
        'Wind_Speed___Resultant', 'datetime']
    df1 = df1.select(cols)
    df1 = df1.withColumn('flag', lit(1))
    schema = StructType([StructField('ds', TimestampType(), True), 
                         StructField('yhat_lower', FloatType(), True),
                         StructField('yhat_upper', FloatType(), True),
                         StructField('yhat', FloatType(), True),
                         StructField('y', FloatType(), True)])
    
    @pandas_udf(schema, PandasUDFType.GROUPED_MAP)
    def forecast_pm25(df):
        #prepare data 
        df['Date'] = df['datetime'].astype('datetime64[ns]')
        df['year'] = df['Date'].dt.year
        df.set_index('Date', inplace=True) 
        df.sort_index(inplace=True)
        v = pd.date_range(start='2016-12-31 23:00:00', periods=18265, freq='H', closed='right')
        newdf = pd.DataFrame(index=v)
        # Fill missing dates 
        historical=pd.merge(newdf, df, how='left', left_index=True, right_index=True)
        historical.interpolate(method='time', inplace=True)
        historical.reset_index(inplace=True)
        historical.rename(columns={'index': 'ds', 'PM2_5___Local_Conditions': 'y'}, inplace=True)
        historical.fillna(0, inplace=True)
        # handle zero and negative values for pm
        for i,item in enumerate(historical['y']):
            if item<=0:
                historical['y'].iloc[i]=historical['y'].iloc[i-1]
            else:
                historical['y'].iloc[i]=item
                
        for i,item in enumerate(historical['PM10_Total_0_10um_STP']):
            if item<=0:
                historical['PM10_Total_0_10um_STP'].iloc[i]=historical['PM10_Total_0_10um_STP'].iloc[i-1]
            else:
                historical['PM10_Total_0_10um_STP'].iloc[i]=item        
         
        for i,item in enumerate(historical['Wind_Speed___Resultant']):
            if item<=0:
                historical['Wind_Speed___Resultant'].iloc[i]=historical['Wind_Speed___Resultant'].iloc[i-1]
            else:
                historical['Wind_Speed___Resultant'].iloc[i]=item
        
        for i,item in enumerate(historical['Wind_Direction___Resultant']):
            if item<=0:
                historical['Wind_Direction___Resultant'].iloc[i]=historical['Wind_Direction___Resultant'].iloc[i-1]
            else:
                historical['Wind_Direction___Resultant'].iloc[i]=item
        # split data into train and test        
        train_df = historical[historical.year != 2019]
        test_df = historical[historical.year == 2019]
        test_df.drop(columns='y', inplace=True)        
        # train model    
        m = Prophet(daily_seasonality=True,
                    weekly_seasonality=True)
        m.add_regressor('PM10_Total_0_10um_STP')
        m.add_regressor('Wind_Speed___Resultant')
        m.add_regressor('Wind_Direction___Resultant')
        m.fit(train_df);
        # predict on test data
        forecast = m.predict(test_df)
        # save plots locally
        plot1 = m.plot(forecast);
        plot2 = m.plot_components(forecast);
        plot1.savefig(r'/home/ags/localdatastore/fbdata/forecast.png')
        plot2.savefig(r'/home/ags/localdatastore/fbdata/cmponents.png')
        # Uncomment the following lines if you want to publish and visualize your graphs as as item.
#         gis = GIS('https://machinename/portal', 'username', 'password')
#         gis.content.add(item_properties={"type": "Image", "title": "Forecast Plot"}, data=r"/home/ags/localdatastore/fbdata/forecast.png")
#         gis.content.add(item_properties={"type": "Image", "title": "Forecase Components2"}, data=r"/home/ags/localdatastore/fbdata/cmponents.png")
        # create df with actual and predicted fields
        cmp_df = forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
        cmp_df.reset_index(inplace=True)
        cmp_df = cmp_df[['ds', 'yhat_lower', 'yhat_upper', 'yhat', 'y']]
        return cmp_df
    res = df1.groupby(['flag']).apply(forecast_pm25)

    res.write.format("webgis").save("predicted_results_on_test_data" + str(dt.now().microsecond))

# %%
run_python_script(code=predict_pm25, layers=[series_data])
# Out:
# [{'type': 'esriJobMessageTypeInformative',
#   'description': 'Executing (RunPythonScript): RunPythonScript "def predict_pm25():\\n    from arcgis.gis import GIS\\n    gis = GIS(\'https://deldevld016.esri.com/portal\', \'admin\', \'esri.agp2\', profile="your_enterprise_portal", verify_cert=False)\\n    from datetime import datetime as dt\\n    from pyspark.sql.functions import concat, col, lit\\n    import pandas as pd\\n    import numpy as np\\n    from fbprophet import Prophet\\n    from pyspark.sql.functions import pandas_udf, PandasUDFType\\n    from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, FloatType, TimestampType\\n    import warnings\\n    warnings.filterwarnings(\'ignore\')\\n    \\n    df1 = layers[0] \\n    cols = [\'Outdoor_Temperature\', \'Ozone\', \'PM10_Total_0_10um_STP\',\\n        \'PM2_5___Local_Conditions\',\\n        \'Wind_Direction___Resultant\',\\n        \'Wind_Speed___Resultant\', \'datetime\']\\n    df1 = df1.select(cols)\\n    df1 = df1.withColumn(\'flag\', lit(1))\\n    schema = StructType([StructField(\'ds\', TimestampType(), True), \\n                         StructField(\'yhat_lower\', FloatType(), True),\\n                         StructField(\'yhat_upper\', FloatType(), True),\\n                         StructField(\'yhat\', FloatType(), True),\\n                         StructField(\'y\', FloatType(), True)])\\n    \\n    @pandas_udf(schema, PandasUDFType.GROUPED_MAP)\\n    def forecast_pm25(df):\\n        #prepare data \\n        df[\'Date\'] = df[\'datetime\'].astype(\'datetime64[ns]\')\\n        df[\'year\'] = df[\'Date\'].dt.year\\n        df.set_index(\'Date\', inplace=True) \\n        df.sort_index(inplace=True)\\n        v = pd.date_range(start=\'2016-12-31 23:00:00\', periods=18265, freq=\'H\', closed=\'right\')\\n        newdf = pd.DataFrame(index=v)\\n        # Fill missing dates \\n        historical=pd.merge(newdf, df, how=\'left\', left_index=True, right_index=True)\\n        historical.interpolate(method=\'time\', inplace=True)\\n        historical.reset_index(inplace=True)\\n        historical.rename(columns={\'index\': \'ds\', \'PM2_5___Local_Conditions\': \'y\'}, inplace=True)\\n        historical.fillna(0, inplace=True)\\n        # handle zero and negative values for pm\\n        for i,item in enumerate(historical[\'y\']):\\n            if item<=0:\\n                historical[\'y\'].iloc[i]=historical[\'y\'].iloc[i-1]\\n            else:\\n                historical[\'y\'].iloc[i]=item\\n                \\n        for i,item in enumerate(historical[\'PM10_Total_0_10um_STP\']):\\n            if item<=0:\\n                historical[\'PM10_Total_0_10um_STP\'].iloc[i]=historical[\'PM10_Total_0_10um_STP\'].iloc[i-1]\\n            else:\\n                historical[\'PM10_Total_0_10um_STP\'].iloc[i]=item        \\n         \\n        for i,item in enumerate(historical[\'Wind_Speed___Resultant\']):\\n            if item<=0:\\n                historical[\'Wind_Speed___Resultant\'].iloc[i]=historical[\'Wind_Speed___Resultant\'].iloc[i-1]\\n            else:\\n                historical[\'Wind_Speed___Resultant\'].iloc[i]=item\\n        \\n        for i,item in enumerate(historical[\'Wind_Direction___Resultant\']):\\n            if item<=0:\\n                historical[\'Wind_Direction___Resultant\'].iloc[i]=historical[\'Wind_Direction___Resultant\'].iloc[i-1]\\n            else:\\n                historical[\'Wind_Direction___Resultant\'].iloc[i]=item\\n        # split data into train and test        \\n        train_df = historical[historical.year != 2019]\\n        test_df = historical[historical.year == 2019]\\n        test_df.drop(columns=\'y\', inplace=True)        \\n        # train model    \\n        m = Prophet(daily_seasonality=True,\\n                    weekly_seasonality=True)\\n        m.add_regressor(\'PM10_Total_0_10um_STP\')\\n        m.add_regressor(\'Wind_Speed___Resultant\')\\n        m.add_regressor(\'Wind_Direction___Resultant\')\\n        m.fit(train_df);\\n        # pred ...
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Start Time: Fri Jul  3 08:50:44 2020'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Using URL based GPRecordSet param: https://deldevld016.esri.com/server/rest/services/Hosted/timeseries_data_17_18_19_1station897490/FeatureServer/0'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101028","message":"Starting new distributed job with 206 tasks.","params":{"totalTasks":"206"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"0/206 distributed tasks completed.","params":{"completedTasks":"0","totalTasks":"206"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"7/206 distributed tasks completed.","params":{"completedTasks":"7","totalTasks":"206"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101029","message":"206/206 distributed tasks completed.","params":{"completedTasks":"206","totalTasks":"206"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101081","message":"Finished writing results:"}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101082","message":"* Count of features = 744","params":{"resultCount":"744"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101083","message":"* Spatial extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101084","message":"* Temporal extent = None","params":{"extent":"None"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': '{"messageCode":"BD_101226","message":"Feature service layer created: https://deldevld016.esri.com/server/rest/services/Hosted/predicted_results_on_test_data718244/FeatureServer/0","params":{"serviceUrl":"https://deldevld016.esri.com/server/rest/services/Hosted/predicted_results_on_test_data718244/FeatureServer/0"}}'},
#  {'type': 'esriJobMessageTypeInformative',
#   'description': 'Succeeded at Fri Jul  3 08:51:28 2020 (Elapsed Time: 44.37 seconds)'}]

# %%
predicted_item = gis.content.search('predicted_results_on_test_data')

# %%
predicted_item[0]
# Out:
# <Item title:"predicted_results_on_test_data854829" type:Table Layer owner:admin>

# %%
predicted_df = predicted_item[0].tables[0].query().sdf

# %%
predicted_df.columns
# Out:
# Index(['ds', 'yhat_lower', 'yhat_upper', 'yhat', 'y', 'globalid', 'OBJECTID'], dtype='object')

# %%
predicted_df.head()
# Out:
#                    ds  yhat_lower  yhat_upper      yhat    y  \
# 0 2018-12-31 18:30:00    1.357769   15.941110  8.691076  5.5
# 1 2018-12-31 19:30:00    1.141512   16.265352  8.773848  5.7
# 2 2018-12-31 20:30:00    0.389374   15.927957  7.641061  5.4
# 3 2018-12-31 21:30:00   -0.164141   15.033084  7.111085  4.4
# 4 2018-12-31 22:30:00   -0.587776   14.489634  7.002420  4.4
#
#                                  globalid  OBJECTID
# 0  {7BCD0AF8-F5B1-4A7E-7118-88589E0A4DAD}        44
# 1  {747EF178-8A36-5CCC-74A3-4BAD71DB0553}       244
# 2  {7D6C9381-7279-AB10-C5F7-AE138BFD6AE0}       444
# 3  {B9BD44CF-F794-87F3-E389-E654CDCE8844}       644
# 4  {B7C8C5C7-1C9E-E66A-CA41-39E5F0D601FA}       844

# %% [markdown]
# dashboard link

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References
